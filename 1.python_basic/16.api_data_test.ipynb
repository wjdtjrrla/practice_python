# %% [markdown]
# #### 조폐공사_지역사랑상품권_결제정보 (api활용 불러오기)

# %%
# !pip install requests
# !pip install xmltodict

from pprint import pprint #보기 편하게
import xmltodict
import pandas as pd
# Out:
# Requirement already satisfied: requests in c:\users\owner\appdata\local\programs\python\python313\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\owner\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\owner\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\owner\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\owner\appdata\local\programs\python\python313\lib\site-packages (from requests) (2024.12.14)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: xmltodict in c:\users\owner\appdata\local\programs\python\python313\lib\site-packages (0.14.2)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
service_key = "dtbWOdJ/Cz5HE0DGLU+CRPe7pOW0NIQBUcGEqsHZaTRiYCI/5+zugwzQjcvuId7NPdg6rUiW+ft3fm7yqyD4pw=="

# %%
# Python3 샘플 코드 #

import requests

url = 'http://apis.data.go.kr/B190001/localGiftsPaymentV3/paymentsV3'
params ={
    'serviceKey' : service_key, 
    'page' : '1', 
    'perPage' : '20',
    'cond[par_gend::EQ]' : 'F'
    }

response = requests.get(url, params=params)
pprint(response.content)
# Out:
# (b'{"currentCount":20,"data":[{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41'
#  b'390000","emd_nm":null,"mbl_use_amt":336,"mbl_user_cnt":12,"par_ag":"02","par'
#  b'_gend":"F","stlm_amt":336,"stlm_nocs":12,"usage_rgn_cd":"41390"},{"card_use_'
#  b'amt":0,"crtr_ym":"201901","emd_cd":"41390000","emd_nm":null,"mbl_use_amt":14'
#  b'810,"mbl_user_cnt":2,"par_ag":"03","par_gend":"F","stlm_amt":14810,"stlm_noc'
#  b's":2,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"'
#  b'41390000","emd_nm":null,"mbl_use_amt":4200,"mbl_user_cnt":3,"par_ag":"04","p'
#  b'ar_gend":"F","stlm_amt":4200,"stlm_nocs":3,"usage_rgn_cd":"41390"},{"card_us'
#  b'e_amt":0,"crtr_ym":"201901","emd_cd":"41390000","emd_nm":null,"mbl_use_amt":'
#  b'65500,"mbl_user_cnt":8,"par_ag":"05","par_gend":"F","stlm_amt":65500,"stlm_n'
#  b'ocs":8,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd"'
#  b':"41390000","emd_nm":null,"mbl_use_amt":50000,"mbl_user_cnt":1,"par_ag":"06"'
#  b',"par_gend":"F","stlm_amt":50000,"stlm_nocs":1,"usage_rgn_cd":"41390"},{"car'
#  b'd_use_amt":0,"crtr_ym":"201901","emd_cd":"41390101","emd_nm":"\xeb\x8c'
#  b'\x80\xec\x95\xbc\xeb\x8f\x99","mbl_use_amt":10,"mbl_user_cnt":1,"par_ag":'
#  b'"04","par_gend":"F","stlm_amt":10,"stlm_nocs":1,"usage_rgn_cd":"41390"},{"ca'
#  b'rd_use_amt":0,"crtr_ym":"201901","emd_cd":"41390101","emd_nm":"\xeb'
#  b'\x8c\x80\xec\x95\xbc\xeb\x8f\x99","mbl_use_amt":500,"mbl_user_cnt":1,"par_ag'
#  b'":"05","par_gend":"F","stlm_amt":500,"stlm_nocs":1,"usage_rgn_cd":"41390"},{'
#  b'"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390102","emd_nm":"\xec\x8b'
#  b'\xa0\xec\xb2\x9c\xeb\x8f\x99","mbl_use_amt":18000,"mbl_user_cnt":3,"par_a'
#  b'g":"05","par_gend":"F","stlm_amt":18000,"stlm_nocs":3,"usage_rgn_cd":"41390"'
#  b'},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390106","emd_nm":'
#  b'"\xec\x9d\x80\xed\x96\x89\xeb\x8f\x99","mbl_use_amt":1000,"mbl_user_cnt":1,'
#  b'"par_ag":"05","par_gend":"F","stlm_amt":1000,"stlm_nocs":1,"usage_rgn_cd":"4'
#  b'1390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390120","emd_nm"'
#  b':"\xed\x95\x98\xec\x83\x81\xeb\x8f\x99","mbl_use_amt":100,"mbl_user_cnt":1,'
#  b'"par_ag":"05","par_gend":"F","stlm_amt":100,"stlm_nocs":1,"usage_rgn_cd":"41'
#  b'390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390129","emd_nm":'
#  b'"\xec\x9e\xa5\xed\x98\x84\xeb\x8f\x99","mbl_use_amt":16014,"mbl_user_cnt":6'
#  b',"par_ag":"03","par_gend":"F","stlm_amt":16014,"stlm_nocs":6,"usage_rgn_cd":'
#  b'"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390129","emd_nm":"'
#  b'\xec\x9e\xa5\xed\x98\x84\xeb\x8f\x99","mbl_use_amt":78900,"mbl_user_cnt":2,'
#  b'"par_ag":"04","par_gend":"F","stlm_amt":78900,"stlm_nocs":2,"usage_rgn_cd":"'
#  b'41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390129","emd_nm'
#  b'":"\xec\x9e\xa5\xed\x98\x84\xeb\x8f\x99","mbl_use_amt":24000,"mbl_user_cnt"'
#  b':1,"par_ag":"05","par_gend":"F","stlm_amt":24000,"stlm_nocs":1,"usage_rgn_cd'
#  b'":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390130","emd_nm"'
#  b':"\xec\x9e\xa5\xea\xb3\xa1\xeb\x8f\x99","mbl_use_amt":16000,"mbl_user_cnt":'
#  b'1,"par_ag":"04","par_gend":"F","stlm_amt":16000,"stlm_nocs":1,"usage_rgn_cd"'
#  b':"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390130","emd_nm":'
#  b'"\xec\x9e\xa5\xea\xb3\xa1\xeb\x8f\x99","mbl_use_amt":114000,"mbl_user_cnt":'
#  b'1,"par_ag":"05","par_gend":"F","stlm_amt":114000,"stlm_nocs":1,"usage_rgn_cd'
#  b'":"41390"},{"card_use_amt":0,"crtr_ym":"201902","emd_cd":"28200110","emd_nm"'
#  b':"\xeb\x85\xbc\xed\x98\x84\xeb\x8f\x99","mbl_use_amt":1,"mbl_user_cnt":1,"p'
#  b'ar_ag":"05","par_gend":"F","stlm_amt":1,"stlm_nocs":1,"usage_rgn_cd":"28200"'
#  b'},{"card_use_amt":0,"crtr_ym":"201902","emd_cd":"41131000","emd_nm":null,"mb'
#  b'l_use_amt":707700,"mbl_user_cnt":11,"par_ag":"03","par_gend":"F","stlm_amt":'
#  b'707700,"stlm_nocs":11,"usage_rgn_cd":"41131"},{"card_use_amt":0,"crtr_ym":"2'
#  b'01902","emd_cd":"41131000","emd_nm":null,"mbl_use_amt":588780,"mbl_user_cnt"'
#  b':6,"par_ag":"04","par_gend":"F","stlm_amt":588780,"stlm_nocs":6,"usage_rgn_c'
#  b'd":"41131"},{"card_use_amt":0,"crtr_ym":"201902","emd_cd":"41131000","emd_nm'
#  b'":null,"mbl_use_amt":251280,"mbl_user_cnt":9,"par_ag":"05","par_gend":"F","s'
#  b'tlm_amt":251280,"stlm_nocs":9,"usage_rgn_cd":"41131"},{"card_use_amt":0,"crt'
#  b'r_ym":"201902","emd_cd":"41131000","emd_nm":null,"mbl_use_amt":101,"mbl_user'
#  b'_cnt":2,"par_ag":"06","par_gend":"F","stlm_amt":101,"stlm_nocs":2,"usage_rgn'
#  b'_cd":"41131"}],"matchCount":1075926,"page":1,"perPage":20,"totalCount":21901'
#  b'82}\n')

# %%
# 바이트형태의 데이터
response.content
# Out:
# b'{"currentCount":20,"data":[{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390000","emd_nm":null,"mbl_use_amt":336,"mbl_user_cnt":12,"par_ag":"02","par_gend":"F","stlm_amt":336,"stlm_nocs":12,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390000","emd_nm":null,"mbl_use_amt":14810,"mbl_user_cnt":2,"par_ag":"03","par_gend":"F","stlm_amt":14810,"stlm_nocs":2,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390000","emd_nm":null,"mbl_use_amt":4200,"mbl_user_cnt":3,"par_ag":"04","par_gend":"F","stlm_amt":4200,"stlm_nocs":3,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390000","emd_nm":null,"mbl_use_amt":65500,"mbl_user_cnt":8,"par_ag":"05","par_gend":"F","stlm_amt":65500,"stlm_nocs":8,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390000","emd_nm":null,"mbl_use_amt":50000,"mbl_user_cnt":1,"par_ag":"06","par_gend":"F","stlm_amt":50000,"stlm_nocs":1,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390101","emd_nm":"\xeb\x8c\x80\xec\x95\xbc\xeb\x8f\x99","mbl_use_amt":10,"mbl_user_cnt":1,"par_ag":"04","par_gend":"F","stlm_amt":10,"stlm_nocs":1,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390101","emd_nm":"\xeb\x8c\x80\xec\x95\xbc\xeb\x8f\x99","mbl_use_amt":500,"mbl_user_cnt":1,"par_ag":"05","par_gend":"F","stlm_amt":500,"stlm_nocs":1,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390102","emd_nm":"\xec\x8b\xa0\xec\xb2\x9c\xeb\x8f\x99","mbl_use_amt":18000,"mbl_user_cnt":3,"par_ag":"05","par_gend":"F","stlm_amt":18000,"stlm_nocs":3,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390106","emd_nm":"\xec\x9d\x80\xed\x96\x89\xeb\x8f\x99","mbl_use_amt":1000,"mbl_user_cnt":1,"par_ag":"05","par_gend":"F","stlm_amt":1000,"stlm_nocs":1,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390120","emd_nm":"\xed\x95\x98\xec\x83\x81\xeb\x8f\x99","mbl_use_amt":100,"mbl_user_cnt":1,"par_ag":"05","par_gend":"F","stlm_amt":100,"stlm_nocs":1,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390129","emd_nm":"\xec\x9e\xa5\xed\x98\x84\xeb\x8f\x99","mbl_use_amt":16014,"mbl_user_cnt":6,"par_ag":"03","par_gend":"F","stlm_amt":16014,"stlm_nocs":6,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390129","emd_nm":"\xec\x9e\xa5\xed\x98\x84\xeb\x8f\x99","mbl_use_amt":78900,"mbl_user_cnt":2,"par_ag":"04","par_gend":"F","stlm_amt":78900,"stlm_nocs":2,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390129","emd_nm":"\xec\x9e\xa5\xed\x98\x84\xeb\x8f\x99","mbl_use_amt":24000,"mbl_user_cnt":1,"par_ag":"05","par_gend":"F","stlm_amt":24000,"stlm_nocs":1,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390130","emd_nm":"\xec\x9e\xa5\xea\xb3\xa1\xeb\x8f\x99","mbl_use_amt":16000,"mbl_user_cnt":1,"par_ag":"04","par_gend":"F","stlm_amt":16000,"stlm_nocs":1,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201901","emd_cd":"41390130","emd_nm":"\xec\x9e\xa5\xea\xb3\xa1\xeb\x8f\x99","mbl_use_amt":114000,"mbl_user_cnt":1,"par_ag":"05","par_gend":"F","stlm_amt":114000,"stlm_nocs":1,"usage_rgn_cd":"41390"},{"card_use_amt":0,"crtr_ym":"201902","emd_cd":"28200110","emd_nm":"\xeb\x85\xbc\xed\x98\x84\xeb\x8f\x99","mbl_use_amt":1,"mbl_user_cnt":1,"par_ag":"05","par_gend":"F","stlm_amt":1,"stlm_nocs":1,"usage_rgn_cd":"28200"},{"card_use_amt":0,"crtr_ym":"201902","emd_cd":"41131000","emd_nm":null,"mbl_use_amt":707700,"mbl_user_cnt":11,"par_ag":"03","par_gend":"F","stlm_amt":707700,"stlm_nocs":11,"usage_rgn_cd":"41131"},{"card_use_amt":0,"crtr_ym":"201902","emd_cd":"41131000","emd_nm":null,"mbl_use_amt":588780,"mbl_user_cnt":6,"par_ag":"04","par_gend":"F","stlm_amt":588780,"stlm_nocs":6,"usage_rgn_cd":"41131"},{"card_use_amt":0,"crtr_ym":"201902","emd_cd":"41131000","emd_nm":null,"mbl_use_amt":251280,"mbl_user_cnt":9,"par_ag":"05","par_gend":"F","stlm_amt":251280,"stlm ...

# %%
# json형태로 변환
res_data = response.json()
print(res_data)
# Out:
# {'currentCount': 20, 'data': [{'card_use_amt': 0, 'crtr_ym': '201901', 'emd_cd': '41390000', 'emd_nm': None, 'mbl_use_amt': 336, 'mbl_user_cnt': 12, 'par_ag': '02', 'par_gend': 'F', 'stlm_amt': 336, 'stlm_nocs': 12, 'usage_rgn_cd': '41390'}, {'card_use_amt': 0, 'crtr_ym': '201901', 'emd_cd': '41390000', 'emd_nm': None, 'mbl_use_amt': 14810, 'mbl_user_cnt': 2, 'par_ag': '03', 'par_gend': 'F', 'stlm_amt': 14810, 'stlm_nocs': 2, 'usage_rgn_cd': '41390'}, {'card_use_amt': 0, 'crtr_ym': '201901', 'emd_cd': '41390000', 'emd_nm': None, 'mbl_use_amt': 4200, 'mbl_user_cnt': 3, 'par_ag': '04', 'par_gend': 'F', 'stlm_amt': 4200, 'stlm_nocs': 3, 'usage_rgn_cd': '41390'}, {'card_use_amt': 0, 'crtr_ym': '201901', 'emd_cd': '41390000', 'emd_nm': None, 'mbl_use_amt': 65500, 'mbl_user_cnt': 8, 'par_ag': '05', 'par_gend': 'F', 'stlm_amt': 65500, 'stlm_nocs': 8, 'usage_rgn_cd': '41390'}, {'card_use_amt': 0, 'crtr_ym': '201901', 'emd_cd': '41390000', 'emd_nm': None, 'mbl_use_amt': 50000, 'mbl_user_cnt': 1, 'par_ag': '06', 'par_gend': 'F', 'stlm_amt': 50000, 'stlm_nocs': 1, 'usage_rgn_cd': '41390'}, {'card_use_amt': 0, 'crtr_ym': '201901', 'emd_cd': '41390101', 'emd_nm': '대야동', 'mbl_use_amt': 10, 'mbl_user_cnt': 1, 'par_ag': '04', 'par_gend': 'F', 'stlm_amt': 10, 'stlm_nocs': 1, 'usage_rgn_cd': '41390'}, {'card_use_amt': 0, 'crtr_ym': '201901', 'emd_cd': '41390101', 'emd_nm': '대야동', 'mbl_use_amt': 500, 'mbl_user_cnt': 1, 'par_ag': '05', 'par_gend': 'F', 'stlm_amt': 500, 'stlm_nocs': 1, 'usage_rgn_cd': '41390'}, {'card_use_amt': 0, 'crtr_ym': '201901', 'emd_cd': '41390102', 'emd_nm': '신천동', 'mbl_use_amt': 18000, 'mbl_user_cnt': 3, 'par_ag': '05', 'par_gend': 'F', 'stlm_amt': 18000, 'stlm_nocs': 3, 'usage_rgn_cd': '41390'}, {'card_use_amt': 0, 'crtr_ym': '201901', 'emd_cd': '41390106', 'emd_nm': '은행동', 'mbl_use_amt': 1000, 'mbl_user_cnt': 1, 'par_ag': '05', 'par_gend': 'F', 'stlm_amt': 1000, 'stlm_nocs': 1, 'usage_rgn_cd': '41390'}, {'card_use_amt': 0, 'crtr_ym': '201901', 'emd_cd': '41390120', 'emd_nm': '하상동', 'mbl_use_amt': 100, 'mbl_user_cnt': 1, 'par_ag': '05', 'par_gend': 'F', 'stlm_amt': 100, 'stlm_nocs': 1, 'usage_rgn_cd': '41390'}, {'card_use_amt': 0, 'crtr_ym': '201901', 'emd_cd': '41390129', 'emd_nm': '장현동', 'mbl_use_amt': 16014, 'mbl_user_cnt': 6, 'par_ag': '03', 'par_gend': 'F', 'stlm_amt': 16014, 'stlm_nocs': 6, 'usage_rgn_cd': '41390'}, {'card_use_amt': 0, 'crtr_ym': '201901', 'emd_cd': '41390129', 'emd_nm': '장현동', 'mbl_use_amt': 78900, 'mbl_user_cnt': 2, 'par_ag': '04', 'par_gend': 'F', 'stlm_amt': 78900, 'stlm_nocs': 2, 'usage_rgn_cd': '41390'}, {'card_use_amt': 0, 'crtr_ym': '201901', 'emd_cd': '41390129', 'emd_nm': '장현동', 'mbl_use_amt': 24000, 'mbl_user_cnt': 1, 'par_ag': '05', 'par_gend': 'F', 'stlm_amt': 24000, 'stlm_nocs': 1, 'usage_rgn_cd': '41390'}, {'card_use_amt': 0, 'crtr_ym': '201901', 'emd_cd': '41390130', 'emd_nm': '장곡동', 'mbl_use_amt': 16000, 'mbl_user_cnt': 1, 'par_ag': '04', 'par_gend': 'F', 'stlm_amt': 16000, 'stlm_nocs': 1, 'usage_rgn_cd': '41390'}, {'card_use_amt': 0, 'crtr_ym': '201901', 'emd_cd': '41390130', 'emd_nm': '장곡동', 'mbl_use_amt': 114000, 'mbl_user_cnt': 1, 'par_ag': '05', 'par_gend': 'F', 'stlm_amt': 114000, 'stlm_nocs': 1, 'usage_rgn_cd': '41390'}, {'card_use_amt': 0, 'crtr_ym': '201902', 'emd_cd': '28200110', 'emd_nm': '논현동', 'mbl_use_amt': 1, 'mbl_user_cnt': 1, 'par_ag': '05', 'par_gend': 'F', 'stlm_amt': 1, 'stlm_nocs': 1, 'usage_rgn_cd': '28200'}, {'card_use_amt': 0, 'crtr_ym': '201902', 'emd_cd': '41131000', 'emd_nm': None, 'mbl_use_amt': 707700, 'mbl_user_cnt': 11, 'par_ag': '03', 'par_gend': 'F', 'stlm_amt': 707700, 'stlm_nocs': 11, 'usage_rgn_cd': '41131'}, {'card_use_amt': 0, 'crtr_ym': '201902', 'emd_cd': '41131000', 'emd_nm': None, 'mbl_use_amt': 588780, 'mbl_user_cnt': 6, 'par_ag': '04', 'par_gend': 'F', 'stlm_amt': 588780, 'stlm_nocs': 6, 'usage_rgn_cd': '41131'}, {'card_use_amt': 0, 'crtr_ym': '201902', 'emd_cd': '41131000', 'emd_nm': None, 'mbl_use_amt': 251280, 'mbl_user_cnt': 9, 'par_a ...

# %%
data = res_data.get('data',[])

# %%
pd.DataFrame(data).to_csv('test1.csv',index=False)

# %%
pd.read_csv('./test1.csv')
# Out:
#     card_use_amt  crtr_ym    emd_cd emd_nm  mbl_use_amt  mbl_user_cnt  par_ag  \
# 0              0   201901  41390000    NaN          336            12       2
# 1              0   201901  41390000    NaN        14810             2       3
# 2              0   201901  41390000    NaN         4200             3       4
# 3              0   201901  41390000    NaN        65500             8       5
# 4              0   201901  41390000    NaN        50000             1       6
# 5              0   201901  41390101    대야동           10             1       4
# 6              0   201901  41390101    대야동          500             1       5
# 7              0   201901  41390102    신천동        18000             3       5
# 8              0   201901  41390106    은행동         1000             1       5
# 9              0   201901  41390120    하상동          100             1       5
# 10             0   201901  41390129    장현동        16014             6       3
# 11             0   201901  41390129    장현동        78900             2       4
# 12             0   201901  41390129    장현동        24000             1       5
# 13             0   201901  41390130    장곡동        16000             1       4
# 14             0   201901  41390130    장곡동       114000             1       5
# 15             0   201902  28200110    논현동            1             1       5
# 16             0   201902  41131000    NaN       707700            11       3
# 17             0   201902  41131000    NaN       588780             6       4
# 18             0   201902  41131000    NaN       251280             9       5
# 19             0   201902  41131000    NaN          101             2       6
#
#    par_gend  stlm_amt  stlm_nocs  usage_rgn_cd
# 0         F       336         12         41390
# 1         F     14810          2         41390
# 2         F      4200          3         41390
# 3         F     65500          8         41390
# 4         F     50000          1         41390
# 5         F        10          1         41390
# 6         F       500          1         41390
# 7         F     18000          3         41390
# 8         F      1000          1         41390
# 9         F       100          1         41390
# 10        F     16014          6         41390
# 11        F     78900          2         41390
# 12        F     24000          1         41390
# 13        F     16000          1         41390
# 14        F    114000          1         41390
# 15        F         1          1         28200
# 16        F    707700         11         41131
# 17        F    588780          6         41131
# 18        F    251280          9         41131
# 19        F       101          2         41131

# %% [markdown]
# #### 두 번째 데이터

# %%
# !pip install requests
# !pip install xmltodict

from pprint import pprint #보기 편하게
import json
import xmltodict
import pandas as pd
import requests
# Out:
# Requirement already satisfied: requests in c:\users\owner\appdata\local\programs\python\python313\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\owner\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\owner\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\owner\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\owner\appdata\local\programs\python\python313\lib\site-packages (from requests) (2024.12.14)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: xmltodict in c:\users\owner\appdata\local\programs\python\python313\lib\site-packages (0.14.2)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
url = "https://dataapi.wehago.com/data/?dataset_key=DATASET_KTNET_68"

header = {
    'apicode' : 'f865e7be-5f88-49ff-a462-31b3c97b582e'
}

response = requests.get(url,headers=header)

# %%
response.content
# Out:
# b'{"schema": {"fields": [{"number": 1, "column_code": "STDR_DTTE", "column_name": "\\uae30\\uc900 \\uc77c\\uc790", "data_type": "string", "column_desc": "YYYYMMDD"}, {"number": 2, "column_code": "EHGT_SE", "column_name": "\\ud658\\uc728 \\uad6c\\ubd84", "data_type": "string", "column_desc": "1: \\uc804\\uc2e0\\ud658\\ub9e4\\ub3c4\\uc728(\\uacfc\\uc138\\ud658\\uc728)"}, {"number": 3, "column_code": "CRNCY_CODE", "column_name": "\\ud1b5\\ud654 \\ucf54\\ub4dc", "data_type": "string", "column_desc": "\\ud1b5\\ud654\\ucf54\\ub4dc"}, {"number": 4, "column_code": "EHGT", "column_name": "\\ud658\\uc728", "data_type": "decimal", "column_desc": "\\ud658\\uc728"}]}, "data": [{"index": 0, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "AED", "EHGT": 337.0}, {"index": 1, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "ATS", "EHGT": 98.0}, {"index": 2, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "AUD", "EHGT": 802.0}, {"index": 3, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "BDT", "EHGT": 15.0}, {"index": 4, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "BEF", "EHGT": 33.0}, {"index": 5, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "BHD", "EHGT": 3282.0}, {"index": 6, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "BRL", "EHGT": 211.0}, {"index": 7, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "CAD", "EHGT": 880.0}, {"index": 8, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "CHF", "EHGT": 1278.0}, {"index": 9, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "CLP", "EHGT": 2.0}, {"index": 10, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "CNY", "EHGT": 174.0}, {"index": 11, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "CZK", "EHGT": 49.0}, {"index": 12, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "DEM", "EHGT": 687.0}, {"index": 13, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "DKK", "EHGT": 180.0}, {"index": 14, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "EGP", "EHGT": 79.0}, {"index": 15, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "ESP", "EHGT": 808.0}, {"index": 16, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "EUR", "EHGT": 1344.0}, {"index": 17, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "FIM", "EHGT": 226.0}, {"index": 18, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "FRF", "EHGT": 205.0}, {"index": 19, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "GBP", "EHGT": 1519.0}, {"index": 20, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "HKD", "EHGT": 160.0}, {"index": 21, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "HUF", "EHGT": 4.0}, {"index": 22, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "IDR", "EHGT": 8.0}, {"index": 23, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "ILS", "EHGT": 353.0}, {"index": 24, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "INR", "EHGT": 17.0}, {"index": 25, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "ITL", "EHGT": 69.0}, {"index": 26, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "JPY", "EHGT": 1155.0}, {"index": 27, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "KES", "EHGT": 12.0}, {"index": 28, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "KWD", "EHGT": 4005.0}, {"index": 29, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "KZT", "EHGT": 3.0}, {"index": 30, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "MNT", "EHGT": 0.0}, {"index": 31, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "MOP", "EHGT": 155.0}, {"index": 32, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "MXN", "EHGT": 51.0}, {"index": 33, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "MYR", "EHGT": 286.0}, {"index": 34, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "NLG", "EHGT": 610.0}, {"index": 35, "STDR_DTTE": "20200513", "EHGT_SE": "1", "CRNCY_CODE": "NOK", "EHGT": 122.0}, {"index": 36, "STDR_DTTE": "20200513", ...

# %%
json.loads(response.content)
# ['기준 일자','환율 구분','통화 코드','환율']
# Out:
# {'schema': {'fields': [{'number': 1,
#     'column_code': 'STDR_DTTE',
#     'column_name': '기준 일자',
#     'data_type': 'string',
#     'column_desc': 'YYYYMMDD'},
#    {'number': 2,
#     'column_code': 'EHGT_SE',
#     'column_name': '환율 구분',
#     'data_type': 'string',
#     'column_desc': '1: 전신환매도율(과세환율)'},
#    {'number': 3,
#     'column_code': 'CRNCY_CODE',
#     'column_name': '통화 코드',
#     'data_type': 'string',
#     'column_desc': '통화코드'},
#    {'number': 4,
#     'column_code': 'EHGT',
#     'column_name': '환율',
#     'data_type': 'decimal',
#     'column_desc': '환율'}]},
#  'data': [{'index': 0,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 337.0},
#   {'index': 1,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 98.0},
#   {'index': 2,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 802.0},
#   {'index': 3,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 15.0},
#   {'index': 4,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 33.0},
#   {'index': 5,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3282.0},
#   {'index': 6,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 211.0},
#   {'index': 7,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 880.0},
#   {'index': 8,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1278.0},
#   {'index': 9,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 2.0},
#   {'index': 10,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 174.0},
#   {'index': 11,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 49.0},
#   {'index': 12,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 687.0},
#   {'index': 13,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 180.0},
#   {'index': 14,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 79.0},
#   {'index': 15,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 808.0},
#   {'index': 16,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1344.0},
#   {'index': 17,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 226.0},
#   {'index': 18,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 205.0},
#   {'index': 19,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1519.0},
#   {'index': 20,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 160.0},
#   {'index': 21,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 22,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 8.0},
#   {'index': 23,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 353.0},
#   {'index': 24,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 17.0},
#   {'index': 25,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 69.0},
#   {'index': 26,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1155.0},
#   {'index': 27,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 12.0},
#   {'index': 28,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 4005.0},
#   {'index': 29,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 30,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 31,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 155.0},
#   {'index': 32,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 51.0},
#   {'index': 33,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 286.0},
#   {'index': 34,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 610.0},
#   {'index': 35,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 122.0},
#   {'index': 36,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 37,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 753.0},
#   {'index': 38,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 25.0},
#   {'index': 39,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 8.0},
#   {'index': 40,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 295.0},
#   {'index': 41,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 338.0},
#   {'index': 42,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 17.0},
#   {'index': 43,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 330.0},
#   {'index': 44,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 127.0},
#   {'index': 45,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 873.0},
#   {'index': 46,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 45.0},
#   {'index': 47,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 39.0},
#   {'index': 48,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 177.0},
#   {'index': 49,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 41.0},
#   {'index': 50,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1238.0},
#   {'index': 51,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 52,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 67870.0},
#   {'index': 53,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 67.0},
#   {'index': 54,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 328.0},
#   {'index': 55,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 100.0},
#   {'index': 56,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 844.0},
#   {'index': 57,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 58,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 34.0},
#   {'index': 59,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3195.0},
#   {'index': 60,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 243.0},
#   {'index': 61,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 900.0},
#   {'index': 62,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1279.0},
#   {'index': 63,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 2.0},
#   {'index': 64,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 170.0},
#   {'index': 65,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 52.0},
#   {'index': 66,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 702.0},
#   {'index': 67,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 184.0},
#   {'index': 68,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 75.0},
#   {'index': 69,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 825.0},
#   {'index': 70,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1373.0},
#   {'index': 71,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 231.0},
#   {'index': 72,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 209.0},
#   {'index': 73,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1538.0},
#   {'index': 74,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 156.0},
#   {'index': 75,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 76,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 9.0},
#   {'index': 77,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 352.0},
#   {'index': 78,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 16.0},
#   {'index': 79,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 71.0},
#   {'index': 80,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1128.0},
#   {'index': 81,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 11.0},
#   {'index': 82,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 3923.0},
#   {'index': 83,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 84,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 85,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 151.0},
#   {'index': 86,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 55.0},
#   {'index': 87,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 284.0},
#   {'index': 88,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 623.0},
#   {'index': 89,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 130.0},
#   {'index': 90,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 91,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 788.0},
#   {'index': 92,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 24.0},
#   {'index': 93,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 7.0},
#   {'index': 94,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 309.0},
#   {'index': 95,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 329.0},
#   {'index': 96,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 18.0},
#   {'index': 97,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 321.0},
#   {'index': 98,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 131.0},
#   {'index': 99,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 872.0},
#   {'index': 100,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 46.0},
#   {'index': 101,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 39.0},
#   {'index': 102,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 178.0},
#   {'index': 103,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 41.0},
#   {'index': 104,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1206.0},
#   {'index': 105,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 106,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 66696.0},
#   {'index': 107,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 73.0},
#   {'index': 108,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 334.0},
#   {'index': 109,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 100.0},
#   {'index': 110,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 844.0},
#   {'index': 111,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 112,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 34.0},
#   {'index': 113,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3249.0},
#   {'index': 114,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 235.0},
#   {'index': 115,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 904.0},
#   {'index': 116,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1293.0},
#   {'index': 117,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 2.0},
#   {'index': 118,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 173.0},
#   {'index': 119,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 52.0},
#   {'index': 120,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 705.0},
#   {'index': 121,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 185.0},
#   {'index': 122,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 76.0},
#   {'index': 123,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 829.0},
#   {'index': 124,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1379.0},
#   {'index': 125,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 232.0},
#   {'index': 126,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 210.0},
#   {'index': 127,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1540.0},
#   {'index': 128,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 158.0},
#   {'index': 129,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 130,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 9.0},
#   {'index': 131,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 356.0},
#   {'index': 132,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 16.0},
#   {'index': 133,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 71.0},
#   {'index': 134,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1146.0},
#   {'index': 135,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 12.0},
#   {'index': 136,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 3987.0},
#   {'index': 137,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 138,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 139,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 154.0},
#   {'index': 140,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 55.0},
#   {'index': 141,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 287.0},
#   {'index': 142,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 626.0},
#   {'index': 143,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 129.0},
#   {'index': 144,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 145,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 792.0},
#   {'index': 146,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 25.0},
#   {'index': 147,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 7.0},
#   {'index': 148,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 309.0},
#   {'index': 149,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 337.0},
#   {'index': 150,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 18.0},
#   {'index': 151,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 327.0},
#   {'index': 152,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 132.0},
#   {'index': 153,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 880.0},
#   {'index': 154,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 46.0},
#   {'index': 155,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 39.0},
#   {'index': 156,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 179.0},
#   {'index': 157,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 41.0},
#   {'index': 158,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1226.0},
#   {'index': 159,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 160,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 68068.0},
#   {'index': 161,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 71.0},
#   {'index': 162,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 330.0},
#   {'index': 163,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 99.0},
#   {'index': 164,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 840.0},
#   {'index': 165,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 166,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 34.0},
#   {'index': 167,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3214.0},
#   {'index': 168,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 229.0},
#   {'index': 169,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 894.0},
#   {'index': 170,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1283.0},
#   {'index': 171,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 2.0},
#   {'index': 172,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 172.0},
#   {'index': 173,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 51.0},
#   {'index': 174,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 698.0},
#   {'index': 175,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 183.0},
#   {'index': 176,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 75.0},
#   {'index': 177,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 821.0},
#   {'index': 178,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1366.0},
#   {'index': 179,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 230.0},
#   {'index': 180,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 208.0},
#   {'index': 181,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1514.0},
#   {'index': 182,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 157.0},
#   {'index': 183,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 184,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 9.0},
#   {'index': 185,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 352.0},
#   {'index': 186,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 16.0},
#   {'index': 187,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 71.0},
#   {'index': 188,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1129.0},
#   {'index': 189,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 11.0},
#   {'index': 190,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 3944.0},
#   {'index': 191,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 192,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 193,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 152.0},
#   {'index': 194,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 54.0},
#   {'index': 195,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 283.0},
#   {'index': 196,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 620.0},
#   {'index': 197,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 128.0},
#   {'index': 198,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 199,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 787.0},
#   {'index': 200,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 24.0},
#   {'index': 201,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 7.0},
#   {'index': 202,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 305.0},
#   {'index': 203,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 331.0},
#   {'index': 204,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 17.0},
#   {'index': 205,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 324.0},
#   {'index': 206,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 130.0},
#   {'index': 207,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 871.0},
#   {'index': 208,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 45.0},
#   {'index': 209,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 39.0},
#   {'index': 210,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 177.0},
#   {'index': 211,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 41.0},
#   {'index': 212,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1213.0},
#   {'index': 213,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 214,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 68801.0},
#   {'index': 215,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 71.0},
#   {'index': 216,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 326.0},
#   {'index': 217,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 103.0},
#   {'index': 218,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 873.0},
#   {'index': 219,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 220,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 35.0},
#   {'index': 221,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3180.0},
#   {'index': 222,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 227.0},
#   {'index': 223,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 916.0},
#   {'index': 224,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1308.0},
#   {'index': 225,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 2.0},
#   {'index': 226,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 176.0},
#   {'index': 227,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 54.0},
#   {'index': 228,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 725.0},
#   {'index': 229,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 190.0},
#   {'index': 230,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 76.0},
#   {'index': 231,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 852.0},
#   {'index': 232,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1417.0},
#   {'index': 233,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 238.0},
#   {'index': 234,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 216.0},
#   {'index': 235,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1578.0},
#   {'index': 236,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 155.0},
#   {'index': 237,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 238,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 8.0},
#   {'index': 239,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 355.0},
#   {'index': 240,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 16.0},
#   {'index': 241,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 73.0},
#   {'index': 242,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1128.0},
#   {'index': 243,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 11.0},
#   {'index': 244,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 3919.0},
#   {'index': 245,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 246,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 247,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 150.0},
#   {'index': 248,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 55.0},
#   {'index': 249,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 288.0},
#   {'index': 250,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 643.0},
#   {'index': 251,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 134.0},
#   {'index': 252,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 253,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 803.0},
#   {'index': 254,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 25.0},
#   {'index': 255,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 7.0},
#   {'index': 256,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 320.0},
#   {'index': 257,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 330.0},
#   {'index': 258,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 16.0},
#   {'index': 259,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 320.0},
#   {'index': 260,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 137.0},
#   {'index': 261,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 877.0},
#   {'index': 262,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 47.0},
#   {'index': 263,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 38.0},
#   {'index': 264,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 161.0},
#   {'index': 265,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 41.0},
#   {'index': 266,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1199.0},
#   {'index': 267,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 268,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 74415.0},
#   {'index': 269,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 72.0},
#   {'index': 270,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 325.0},
#   {'index': 271,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 103.0},
#   {'index': 272,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 871.0},
#   {'index': 273,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 274,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 35.0},
#   {'index': 275,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3162.0},
#   {'index': 276,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 226.0},
#   {'index': 277,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 904.0},
#   {'index': 278,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1313.0},
#   {'index': 279,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 2.0},
#   {'index': 280,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 176.0},
#   {'index': 281,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 53.0},
#   {'index': 282,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 722.0},
#   {'index': 283,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 190.0},
#   {'index': 284,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 76.0},
#   {'index': 285,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 849.0},
#   {'index': 286,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1413.0},
#   {'index': 287,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 238.0},
#   {'index': 288,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 215.0},
#   {'index': 289,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1537.0},
#   {'index': 290,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 154.0},
#   {'index': 291,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 292,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 8.0},
#   {'index': 293,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 349.0},
#   {'index': 294,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 16.0},
#   {'index': 295,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 73.0},
#   {'index': 296,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1131.0},
#   {'index': 297,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 11.0},
#   {'index': 298,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 3901.0},
#   {'index': 299,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 300,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 301,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 150.0},
#   {'index': 302,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 56.0},
#   {'index': 303,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 289.0},
#   {'index': 304,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 641.0},
#   {'index': 305,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 132.0},
#   {'index': 306,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 307,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 801.0},
#   {'index': 308,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 25.0},
#   {'index': 309,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 7.0},
#   {'index': 310,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 317.0},
#   {'index': 311,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 325.0},
#   {'index': 312,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 16.0},
#   {'index': 313,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 318.0},
#   {'index': 314,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 136.0},
#   {'index': 315,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 876.0},
#   {'index': 316,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 47.0},
#   {'index': 317,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 38.0},
#   {'index': 318,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 159.0},
#   {'index': 319,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 41.0},
#   {'index': 320,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1192.0},
#   {'index': 321,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 322,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 74936.0},
#   {'index': 323,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 73.0},
#   {'index': 324,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 323.0},
#   {'index': 325,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 102.0},
#   {'index': 326,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 869.0},
#   {'index': 327,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 328,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 35.0},
#   {'index': 329,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3148.0},
#   {'index': 330,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 227.0},
#   {'index': 331,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 903.0},
#   {'index': 332,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1307.0},
#   {'index': 333,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 2.0},
#   {'index': 334,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 175.0},
#   {'index': 335,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 53.0},
#   {'index': 336,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 719.0},
#   {'index': 337,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 189.0},
#   {'index': 338,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 75.0},
#   {'index': 339,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 846.0},
#   {'index': 340,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1407.0},
#   {'index': 341,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 237.0},
#   {'index': 342,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 215.0},
#   {'index': 343,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1540.0},
#   {'index': 344,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 153.0},
#   {'index': 345,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 346,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 8.0},
#   {'index': 347,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 347.0},
#   {'index': 348,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 16.0},
#   {'index': 349,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 73.0},
#   {'index': 350,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1133.0},
#   {'index': 351,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 11.0},
#   {'index': 352,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 3882.0},
#   {'index': 353,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 354,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 355,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 149.0},
#   {'index': 356,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 57.0},
#   {'index': 357,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 287.0},
#   {'index': 358,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 639.0},
#   {'index': 359,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 131.0},
#   {'index': 360,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 361,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 803.0},
#   {'index': 362,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 25.0},
#   {'index': 363,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 7.0},
#   {'index': 364,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 316.0},
#   {'index': 365,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 327.0},
#   {'index': 366,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 16.0},
#   {'index': 367,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 317.0},
#   {'index': 368,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 135.0},
#   {'index': 369,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 875.0},
#   {'index': 370,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 47.0},
#   {'index': 371,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 38.0},
#   {'index': 372,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 157.0},
#   {'index': 373,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 41.0},
#   {'index': 374,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1187.0},
#   {'index': 375,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 376,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 73913.0},
#   {'index': 377,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 74.0},
#   {'index': 378,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 322.0},
#   {'index': 379,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 100.0},
#   {'index': 380,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 834.0},
#   {'index': 381,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 382,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 34.0},
#   {'index': 383,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3134.0},
#   {'index': 384,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 215.0},
#   {'index': 385,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 885.0},
#   {'index': 386,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1275.0},
#   {'index': 387,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 2.0},
#   {'index': 388,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 173.0},
#   {'index': 389,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 51.0},
#   {'index': 390,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 705.0},
#   {'index': 391,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 185.0},
#   {'index': 392,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 75.0},
#   {'index': 393,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 829.0},
#   {'index': 394,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1380.0},
#   {'index': 395,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 232.0},
#   {'index': 396,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 210.0},
#   {'index': 397,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1507.0},
#   {'index': 398,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 152.0},
#   {'index': 399,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 400,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 8.0},
#   {'index': 401,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 340.0},
#   {'index': 402,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 16.0},
#   {'index': 403,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 71.0},
#   {'index': 404,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1121.0},
#   {'index': 405,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 11.0},
#   {'index': 406,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 3859.0},
#   {'index': 407,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 408,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 409,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 148.0},
#   {'index': 410,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 53.0},
#   {'index': 411,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 284.0},
#   {'index': 412,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 626.0},
#   {'index': 413,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 124.0},
#   {'index': 414,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 415,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 774.0},
#   {'index': 416,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 24.0},
#   {'index': 417,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 7.0},
#   {'index': 418,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 304.0},
#   {'index': 419,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 325.0},
#   {'index': 420,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 15.0},
#   {'index': 421,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 315.0},
#   {'index': 422,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 130.0},
#   {'index': 423,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 860.0},
#   {'index': 424,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 46.0},
#   {'index': 425,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 37.0},
#   {'index': 426,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 155.0},
#   {'index': 427,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 40.0},
#   {'index': 428,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1182.0},
#   {'index': 429,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 430,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 70999.0},
#   {'index': 431,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 70.0},
#   {'index': 432,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 322.0},
#   {'index': 433,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 101.0},
#   {'index': 434,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 846.0},
#   {'index': 435,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 436,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 34.0},
#   {'index': 437,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3132.0},
#   {'index': 438,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 208.0},
#   {'index': 439,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 888.0},
#   {'index': 440,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1287.0},
#   {'index': 441,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 1.0},
#   {'index': 442,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 173.0},
#   {'index': 443,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 51.0},
#   {'index': 444,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 708.0},
#   {'index': 445,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 186.0},
#   {'index': 446,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 75.0},
#   {'index': 447,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 832.0},
#   {'index': 448,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1384.0},
#   {'index': 449,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 233.0},
#   {'index': 450,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 211.0},
#   {'index': 451,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1527.0},
#   {'index': 452,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 152.0},
#   {'index': 453,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 454,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 8.0},
#   {'index': 455,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 345.0},
#   {'index': 456,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 16.0},
#   {'index': 457,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 71.0},
#   {'index': 458,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1119.0},
#   {'index': 459,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 11.0},
#   {'index': 460,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 3857.0},
#   {'index': 461,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 462,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 463,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 148.0},
#   {'index': 464,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 55.0},
#   {'index': 465,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 284.0},
#   {'index': 466,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 628.0},
#   {'index': 467,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 127.0},
#   {'index': 468,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 469,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 784.0},
#   {'index': 470,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 24.0},
#   {'index': 471,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 7.0},
#   {'index': 472,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 308.0},
#   {'index': 473,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 325.0},
#   {'index': 474,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 15.0},
#   {'index': 475,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 315.0},
#   {'index': 476,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 132.0},
#   {'index': 477,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 866.0},
#   {'index': 478,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 46.0},
#   {'index': 479,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 37.0},
#   {'index': 480,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 152.0},
#   {'index': 481,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 41.0},
#   {'index': 482,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1181.0},
#   {'index': 483,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 484,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 72210.0},
#   {'index': 485,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 72.0},
#   {'index': 486,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 318.0},
#   {'index': 487,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 100.0},
#   {'index': 488,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 844.0},
#   {'index': 489,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 490,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 34.0},
#   {'index': 491,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3097.0},
#   {'index': 492,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 212.0},
#   {'index': 493,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 889.0},
#   {'index': 494,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1283.0},
#   {'index': 495,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 1.0},
#   {'index': 496,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 173.0},
#   {'index': 497,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 51.0},
#   {'index': 498,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 706.0}]}

# %%
data2 = json.loads(response.content)
# data2 = response.json()

# %%
df = data2['data']

# %%
df_test = pd.DataFrame(df)

# %%
df_test.head(3)
# Out:
#    index STDR_DTTE EHGT_SE CRNCY_CODE   EHGT
# 0      0  20200513       1        AED  337.0
# 1      1  20200513       1        ATS   98.0
# 2      2  20200513       1        AUD  802.0

# %%
df_test.columns
# Out:
# Index(['index', 'STDR_DTTE', 'EHGT_SE', 'CRNCY_CODE', 'EHGT'], dtype='object')

# %%
df_test.drop(
    columns=['index'],
    inplace=True
)

# %%
df_test
# Out:
#     STDR_DTTE EHGT_SE CRNCY_CODE    EHGT
# 0    20200513       1        AED   337.0
# 1    20200513       1        ATS    98.0
# 2    20200513       1        AUD   802.0
# 3    20200513       1        BDT    15.0
# 4    20200513       1        BEF    33.0
# ..        ...     ...        ...     ...
# 494  20201012       1        CHF  1283.0
# 495  20201012       1        CLP     1.0
# 496  20201012       1        CNY   173.0
# 497  20201012       1        CZK    51.0
# 498  20201012       1        DEM   706.0
#
# [499 rows x 4 columns]

# %%
# df_test.columns =['기준 일자','환율 구분','통화 코드','환율']
# df_test

# %%
df_test.columns
# Out:
# Index(['STDR_DTTE', 'EHGT_SE', 'CRNCY_CODE', 'EHGT'], dtype='object')

# %%
cols_data = data2['schema']['fields']

# %%
cols_data
# Out:
# [{'number': 1,
#   'column_code': 'STDR_DTTE',
#   'column_name': '기준 일자',
#   'data_type': 'string',
#   'column_desc': 'YYYYMMDD'},
#  {'number': 2,
#   'column_code': 'EHGT_SE',
#   'column_name': '환율 구분',
#   'data_type': 'string',
#   'column_desc': '1: 전신환매도율(과세환율)'},
#  {'number': 3,
#   'column_code': 'CRNCY_CODE',
#   'column_name': '통화 코드',
#   'data_type': 'string',
#   'column_desc': '통화코드'},
#  {'number': 4,
#   'column_code': 'EHGT',
#   'column_name': '환율',
#   'data_type': 'decimal',
#   'column_desc': '환율'}]

# %%
#cols_data에서 column_name의 value만 추출하여 리스트로 생성

cols_list = list(
    map(
        lambda x : x['column_name'],
        cols_data
    )
)

# %%
cols_dict = {}
for cols in cols_data:
    #cols는 cols_data의 각 원소들이 대입
    #cols_dict에 key(column_code) : value(column_name)추가
    cols_dict[cols['column_code']] = cols['column_name']

print(cols_dict)
# Out:
# {'STDR_DTTE': '기준 일자', 'EHGT_SE': '환율 구분', 'CRNCY_CODE': '통화 코드', 'EHGT': '환율'}

# %%
df_test.rename(
    columns = cols_dict
)
# Out:
#         기준 일자 환율 구분 통화 코드      환율
# 0    20200513     1   AED   337.0
# 1    20200513     1   ATS    98.0
# 2    20200513     1   AUD   802.0
# 3    20200513     1   BDT    15.0
# 4    20200513     1   BEF    33.0
# ..        ...   ...   ...     ...
# 494  20201012     1   CHF  1283.0
# 495  20201012     1   CLP     1.0
# 496  20201012     1   CNY   173.0
# 497  20201012     1   CZK    51.0
# 498  20201012     1   DEM   706.0
#
# [499 rows x 4 columns]

# %%
df_test.columns = cols_list

# %%
df_test
# Out:
#         기준 일자 환율 구분 통화 코드      환율
# 0    20200513     1   AED   337.0
# 1    20200513     1   ATS    98.0
# 2    20200513     1   AUD   802.0
# 3    20200513     1   BDT    15.0
# 4    20200513     1   BEF    33.0
# ..        ...   ...   ...     ...
# 494  20201012     1   CHF  1283.0
# 495  20201012     1   CLP     1.0
# 496  20201012     1   CNY   173.0
# 497  20201012     1   CZK    51.0
# 498  20201012     1   DEM   706.0
#
# [499 rows x 4 columns]

# %%
df_test.to_excel('./test2.xlsx',index=False)
