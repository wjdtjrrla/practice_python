# %% [markdown]
# ### 절대 모멘텀
# - 파생변수 'STD-YM' 생성 -> index에서 년-월 추출하여 대입
# - 'STD-YM'별 마지막날의 데이터를 month_last_df 저장
# - 전월의 기준이 되는 컬럼의 값을 가진 파생변수 생성
# - 전년도의 기준이 되는 컬럼의 값을 가진 파생변수 생성
# - 전월의 데이터와 전년도의 데이터를 기준으로 거래 내역 생성
# - 수익율 계산

# %%
from datetime import datetime
import pandas as pd
import numpy as np

# %%
# 데이터 로드
df = pd.read_csv('../csv/AAPL.csv', index_col='Date')

# %%
df.head(3)
# Out:
#                 Open      High       Low     Close  Adj Close       Volume
# Date
# 1980-12-12  0.513393  0.515625  0.513393  0.513393   0.410525  117258400.0
# 1980-12-15  0.488839  0.488839  0.486607  0.486607   0.389106   43971200.0
# 1980-12-16  0.453125  0.453125  0.450893  0.450893   0.360548   26432000.0

# %%
# index를 시계열 데이터로 변환
df.index = pd.to_datetime(df.index,utc=True)

# %%
type(df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# STD-YM 파생변수 생성해서 인덱스에서 년도, 월 추출해서 저장
# 컬럼의 데이터였다면 -> df['Date'].dt.strftime('%Y-%m')
# 아래는 인덱스 형태로 묶여있음.
df.index.strftime('%Y-%m')
# Out:
# Index(['1980-12', '1980-12', '1980-12', '1980-12', '1980-12', '1980-12',
#        '1980-12', '1980-12', '1980-12', '1980-12',
#        ...
#        '2019-06', '2019-06', '2019-06', '2019-06', '2019-06', '2019-06',
#        '2019-06', '2019-06', '2019-06', '2019-06'],
#       dtype='object', name='Date', length=9715)

# %%
df['STD-YM'] = df.index.strftime('%Y-%m')

# %%
df.head(2)
# Out:
#                                Open      High       Low     Close  Adj Close  \
# Date
# 1980-12-12 00:00:00+00:00  0.513393  0.515625  0.513393  0.513393   0.410525
# 1980-12-15 00:00:00+00:00  0.488839  0.488839  0.486607  0.486607   0.389106
#
#                                 Volume   STD-YM
# Date
# 1980-12-12 00:00:00+00:00  117258400.0  1980-12
# 1980-12-15 00:00:00+00:00   43971200.0  1980-12

# %%
# CASE 1 : 월말의 데이터를 출력하는 방법
# 해당방법은 다중 for문 사용해야함
df.loc['1981-12'].tail(1)
test_df = pd.DataFrame()
for year in range(1980, 2026): #년도 반복
    for month in range (1,13): #월 반복
        try:
            idx = f'{year}-{month}'
            df2 = df.loc[idx].tail(1)
            test_df = pd.concat([test_df,df2],axis=0)
        except Exception as e:
            print(e)
            continue
# Out:
# '1980-1'
# '1980-2'
# '1980-3'
# '1980-4'
# '1980-5'
# '1980-6'
# '1980-7'
# '1980-8'
# '1980-9'
# '1980-10'
# '1980-11'
# '2019-7'
# '2019-8'
# '2019-9'
# '2019-10'
# '2019-11'
# '2019-12'
# '2020-1'
# '2020-2'
# '2020-3'
# '2020-4'
# '2020-5'
# '2020-6'
# '2020-7'
# '2020-8'
# '2020-9'
# '2020-10'
# '2020-11'
# '2020-12'
# '2021-1'
# '2021-2'
# '2021-3'
# '2021-4'
# '2021-5'
# '2021-6'
# '2021-7'
# '2021-8'
# '2021-9'
# '2021-10'
# '2021-11'
# '2021-12'
# '2022-1'
# '2022-2'
# '2022-3'
# '2022-4'
# '2022-5'
# '2022-6'
# '2022-7'
# '2022-8'
# '2022-9'
# '2022-10'
# '2022-11'
# '2022-12'
# '2023-1'
# '2023-2'
# '2023-3'
# '2023-4'
# '2023-5'
# '2023-6'
# '2023-7'
# '2023-8'
# '2023-9'
# '2023-10'
# '2023-11'
# '2023-12'
# '2024-1'
# '2024-2'
# '2024-3'
# '2024-4'
# '2024-5'
# '2024-6'
# '2024-7'
# '2024-8'
# '2024-9'
# '2024-10'
# '2024-11'
# '2024-12'
# '2025-1'
# '2025-2'
# '2025-3'
# '2025-4'
# '2025-5'
# '2025-6'
# '2025-7'
# '2025-8'
# '2025-9'
# '2025-10'
# '2025-11'
# '2025-12'

# %%
# CASE 2 : 월말의 데이터를 출력하는 방법
# 현재의 STD-YM 데이터와 다음 인덱스의 STD-YM이 다른 경우
flag = df['STD-YM'] != df.shift(-1)['STD-YM']
df.loc[flag]
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-31 00:00:00+00:00    0.611607    0.611607    0.609375    0.609375
# 1981-01-30 00:00:00+00:00    0.508929    0.508929    0.504464    0.504464
# 1981-02-27 00:00:00+00:00    0.473214    0.477679    0.473214    0.473214
# 1981-03-31 00:00:00+00:00    0.441964    0.441964    0.437500    0.437500
# 1981-04-30 00:00:00+00:00    0.506696    0.511161    0.506696    0.506696
# ...                               ...         ...         ...         ...
# 2019-02-28 00:00:00+00:00  174.320007  174.910004  172.919998  173.149994
# 2019-03-29 00:00:00+00:00  189.830002  190.080002  188.539993  189.949997
# 2019-04-30 00:00:00+00:00  203.059998  203.399994  199.110001  200.669998
# 2019-05-31 00:00:00+00:00  176.229996  177.990005  174.990005  175.070007
# 2019-06-24 00:00:00+00:00  198.539993  200.160004  198.169998  199.169998
#
#                             Adj Close      Volume   STD-YM
# Date
# 1980-12-31 00:00:00+00:00    0.487276   8937600.0  1980-12
# 1981-01-30 00:00:00+00:00    0.403385  11547200.0  1981-01
# 1981-02-27 00:00:00+00:00    0.378397   3690400.0  1981-02
# 1981-03-31 00:00:00+00:00    0.349839   3998400.0  1981-03
# 1981-04-30 00:00:00+00:00    0.405170   3152800.0  1981-04
# ...                               ...         ...      ...
# 2019-02-28 00:00:00+00:00  172.485748  28215400.0  2019-02
# 2019-03-29 00:00:00+00:00  189.221313  23564000.0  2019-03
# 2019-04-30 00:00:00+00:00  199.900192  46534900.0  2019-04
# 2019-05-31 00:00:00+00:00  175.070007  27043600.0  2019-05
# 2019-06-24 00:00:00+00:00  199.169998   9025362.0  2019-06
#
# [463 rows x 7 columns]

# %%
# case3
# unique() 함수 이용
ym_list = df['STD-YM'].unique()
month_last_df = pd.DataFrame()
for ym in ym_list:
    data = df.loc[ym].tail(1)
    month_last_df = pd.concat([month_last_df,data],axis=0)
month_last_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-31 00:00:00+00:00    0.611607    0.611607    0.609375    0.609375
# 1981-01-30 00:00:00+00:00    0.508929    0.508929    0.504464    0.504464
# 1981-02-27 00:00:00+00:00    0.473214    0.477679    0.473214    0.473214
# 1981-03-31 00:00:00+00:00    0.441964    0.441964    0.437500    0.437500
# 1981-04-30 00:00:00+00:00    0.506696    0.511161    0.506696    0.506696
# ...                               ...         ...         ...         ...
# 2019-02-28 00:00:00+00:00  174.320007  174.910004  172.919998  173.149994
# 2019-03-29 00:00:00+00:00  189.830002  190.080002  188.539993  189.949997
# 2019-04-30 00:00:00+00:00  203.059998  203.399994  199.110001  200.669998
# 2019-05-31 00:00:00+00:00  176.229996  177.990005  174.990005  175.070007
# 2019-06-24 00:00:00+00:00  198.539993  200.160004  198.169998  199.169998
#
#                             Adj Close      Volume   STD-YM
# Date
# 1980-12-31 00:00:00+00:00    0.487276   8937600.0  1980-12
# 1981-01-30 00:00:00+00:00    0.403385  11547200.0  1981-01
# 1981-02-27 00:00:00+00:00    0.378397   3690400.0  1981-02
# 1981-03-31 00:00:00+00:00    0.349839   3998400.0  1981-03
# 1981-04-30 00:00:00+00:00    0.405170   3152800.0  1981-04
# ...                               ...         ...      ...
# 2019-02-28 00:00:00+00:00  172.485748  28215400.0  2019-02
# 2019-03-29 00:00:00+00:00  189.221313  23564000.0  2019-03
# 2019-04-30 00:00:00+00:00  199.900192  46534900.0  2019-04
# 2019-05-31 00:00:00+00:00  175.070007  27043600.0  2019-05
# 2019-06-24 00:00:00+00:00  199.169998   9025362.0  2019-06
#
# [463 rows x 7 columns]

# %%
# month_last_df에서
# 전월의 수정종가 데이터를 BF_1M에 대입
# 전년도의 수정종가 데이터를 BF_12M에 대입
month_last_df['BF_1M'] = month_last_df.shift()['Adj Close']

# %%
month_last_df['BF_12M'] = month_last_df.shift(12)['Adj Close']

# %%
month_last_df.iloc[10:15]
# Out:
#                                Open      High       Low     Close  Adj Close  \
# Date
# 1981-10-30 00:00:00+00:00  0.357143  0.359375  0.357143  0.357143   0.285583
# 1981-11-30 00:00:00+00:00  0.334821  0.334821  0.332589  0.332589   0.265949
# 1981-12-31 00:00:00+00:00  0.395089  0.397321  0.395089  0.395089   0.315926
# 1982-01-29 00:00:00+00:00  0.363839  0.366071  0.363839  0.363839   0.290937
# 1982-02-26 00:00:00+00:00  0.325893  0.328125  0.325893  0.325893   0.260594
#
#                                Volume   STD-YM     BF_1M    BF_12M
# Date
# 1981-10-30 00:00:00+00:00  13182400.0  1981-10  0.217757       NaN
# 1981-11-30 00:00:00+00:00   5992000.0  1981-11  0.285583       NaN
# 1981-12-31 00:00:00+00:00  13664000.0  1981-12  0.265949  0.487276
# 1982-01-29 00:00:00+00:00  13288800.0  1982-01  0.315926  0.403385
# 1982-02-26 00:00:00+00:00   4356800.0  1982-02  0.290937  0.378397

# %% [markdown]
# #### 거래 내역 생성
# - 모멘텀 인덱스 : (전월의 수정종가 / 전년도의 수정종가) -1
# - 모멘텀 인덱스가 0보다는 크고, 무한대가 아닌 경우 -> 매수
# * 해당 데이터를 통해 매수 타이밍만 확인.

# %%
# 거래내역 df에 생성
df['trade'] = ''

for idx in month_last_df.index:
    signal = ''
    
    # 절대 모멘텀 계산식
    momentum_index = month_last_df.loc[idx,'BF_1M'] / month_last_df.loc[idx,'BF_12M'] - 1
    
    flag = (momentum_index>0) & (momentum_index != np.inf)
    if flag:
        signal='buy'
    
    print(f'날짜 : {idx}, 모멘텀 인덱스 : {momentum_index}, signal : {signal}')
    df.loc[idx:,'trade'] = signal
# Out:
# 날짜 : 1980-12-31 00:00:00+00:00, 모멘텀 인덱스 : nan, signal :
# 날짜 : 1981-01-30 00:00:00+00:00, 모멘텀 인덱스 : nan, signal :
# 날짜 : 1981-02-27 00:00:00+00:00, 모멘텀 인덱스 : nan, signal :
# 날짜 : 1981-03-31 00:00:00+00:00, 모멘텀 인덱스 : nan, signal :
# 날짜 : 1981-04-30 00:00:00+00:00, 모멘텀 인덱스 : nan, signal :
# 날짜 : 1981-05-29 00:00:00+00:00, 모멘텀 인덱스 : nan, signal :
# 날짜 : 1981-06-30 00:00:00+00:00, 모멘텀 인덱스 : nan, signal :
# 날짜 : 1981-07-31 00:00:00+00:00, 모멘텀 인덱스 : nan, signal :
# 날짜 : 1981-08-31 00:00:00+00:00, 모멘텀 인덱스 : nan, signal :
# 날짜 : 1981-09-30 00:00:00+00:00, 모멘텀 인덱스 : nan, signal :
# 날짜 : 1981-10-30 00:00:00+00:00, 모멘텀 인덱스 : nan, signal :
# 날짜 : 1981-11-30 00:00:00+00:00, 모멘텀 인덱스 : nan, signal :
# 날짜 : 1981-12-31 00:00:00+00:00, 모멘텀 인덱스 : -0.45421280752591964, signal :
# 날짜 : 1982-01-29 00:00:00+00:00, 모멘텀 인덱스 : -0.21681272233722126, signal :
# 날짜 : 1982-02-26 00:00:00+00:00, 모멘텀 인덱스 : -0.23113291067318187, signal :
# 날짜 : 1982-03-31 00:00:00+00:00, 모멘텀 인덱스 : -0.2551030616940936, signal :
# 날짜 : 1982-04-30 00:00:00+00:00, 모멘텀 인덱스 : -0.4052866697929264, signal :
# 날짜 : 1982-05-28 00:00:00+00:00, 모멘텀 인덱스 : -0.554717164627185, signal :
# 날짜 : 1982-06-30 00:00:00+00:00, 모멘텀 인덱스 : -0.4615374255569592, signal :
# 날짜 : 1982-07-30 00:00:00+00:00, 모멘텀 인덱스 : -0.4899993837155231, signal :
# 날짜 : 1982-08-31 00:00:00+00:00, 모멘텀 인덱스 : -0.32919228721460714, signal :
# 날짜 : 1982-09-30 00:00:00+00:00, 모멘텀 인덱스 : 0.18032485752467187, signal : buy
# 날짜 : 1982-10-29 00:00:00+00:00, 모멘텀 인덱스 : -0.0875017070343822, signal :
# 날짜 : 1982-11-30 00:00:00+00:00, 모멘텀 인덱스 : 0.36241535031152594, signal : buy
# 날짜 : 1982-12-31 00:00:00+00:00, 모멘텀 인덱스 : 0.44067598108417805, signal : buy
# 날짜 : 1983-01-31 00:00:00+00:00, 모멘텀 인덱스 : 0.46625901827543426, signal : buy
# 날짜 : 1983-02-28 00:00:00+00:00, 모멘텀 인덱스 : 1.2397292339808281, signal : buy
# 날짜 : 1983-03-31 00:00:00+00:00, 모멘텀 인덱스 : 1.7037060092961487, signal : buy
# 날짜 : 1983-04-29 00:00:00+00:00, 모멘텀 인덱스 : 1.8644079062943635, signal : buy
# 날짜 : 1983-05-31 00:00:00+00:00, 모멘텀 인덱스 : 2.6071392840706724, signal : buy
# 날짜 : 1983-06-30 00:00:00+00:00, 모멘텀 인덱스 : 3.529410795401491, signal : buy
# 날짜 : 1983-07-29 00:00:00+00:00, 모멘텀 인덱스 : 2.620372675962815, signal : buy
# 날짜 : 1983-08-31 00:00:00+00:00, 모멘텀 인덱스 : 0.9375038906872513, signal : buy
# 날짜 : 1983-09-30 00:00:00+00:00, 모멘텀 인덱스 : 1.0410984136242583, signal : buy
# 날짜 : 1983-10-31 00:00:00+00:00, 모멘텀 인덱스 : -0.08866981478363822, signal :
# 날짜 : 1983-11-30 00:00:00+00:00, 모멘텀 인덱스 : -0.2901963541449246, signal :
# 날짜 : 1983-12-30 00:00:00+00:00, 모멘텀 인덱스 : -0.3179922595284923, signal :
# 날짜 : 1984-01-31 00:00:00+00:00, 모멘텀 인덱스 : -0.4036699448308947, signal :
# 날짜 : 1984-02-29 00:00:00+00:00, 모멘텀 인덱스 : -0.4575347091644474, signal :
# 날짜 : 1984-03-30 00:00:00+00:00, 모멘텀 인덱스 : -0.3786982444682765, signal :
# 날짜 : 1984-04-30 00:00:00+00:00, 모멘텀 인덱스 : -0.5099015942398792, signal :
# 날짜 : 1984-05-31 00:00:00+00:00, 모멘텀 인덱스 : -0.4567097572215081, signal :
# 날짜 : 1984-06-29 00:00:00+00:00, 모멘텀 인덱스 : -0.3989772056421337, signal :
# 날짜 : 1984-07-31 00:00:00+00:00, 모멘텀 인덱스 : -0.24014377943110743, signal :
# 날짜 : 1984-08-31 00:00:00+00:00, 모멘텀 인덱스 : -0.31543641826064395, signal :
# 날짜 : 1984-09-28 00:00:00+00:00, 모멘텀 인덱스 : 0.1459457003982374, signal : buy
# 날짜 : 1984-10-31 00:00:00+00:00, 모멘텀 인덱스 : 0.11049788742203592, signal : buy
# 날짜 : 1984-11-30 00:00:00+00:00, 모멘텀 인덱스 : 0.2208588113577854, signal : buy
# 날짜 : 1984-12-31 00:00:00+00:00, 모멘텀 인덱스 : 0.01538267050515163, signal : buy
# 날짜 : 1985-01-31 00:00:00+00:00, 모멘텀 인덱스 : 0.1767701919594351, signal : buy
# 날짜 : 1985-02-28 00:00:00+00:00, 모멘텀 인덱스 : 0.10476299732943462, signal : buy
# 날짜 : 1985-03-29 00:00:00+00:00, 모멘텀 인덱스 : 0.0, signal :
# 날짜 : 1985-04-30 00:00:00+00:00, 모멘텀 인덱스 : -0.29482062820306787, signal :
# 날짜 : 1985-05-31 00:00:00+00:00, 모멘텀 인덱스 : -0.2765962012068214, signal :
# 날짜 : 1985-06-28 00:00:00+00:00, 모멘텀 인덱스 : -0.3443394107247151, signal :
# 날짜 : 1985-07-31 00:00:00+00:00, 모멘텀 인덱스 : -0.29411893946467915, signal :
# 날짜 : 1985-08-30 00:00:00+00:00, 모멘텀 인덱스 : -0.40094398211402305, signal :
# 날짜 : 1985-09-30 00:00:00+00:00, 모멘텀 인덱스 : -0.40298470020598565, signal :
# 날짜 : 1985-10-31 00:00:00+00:00, 모멘텀 인덱스 : -0.36683436892055865, signal :
# 날짜 : 1985-11-29 00:00:00+00:00, 모멘텀 인덱스 : -0.24747317547989867, signal :
# 날짜 : 1985-12-31 00:00:00+00:00, 모멘텀 인덱스 : -0.3090146196018083, signal :
# 날짜 : 1986-01-31 00:00:00+00:00, 모멘텀 인덱스 : -0.24137939361740657, signal :
# 날짜 : 1986-02-28 00:00:00+00:00, 모멘텀 인덱스 : -0.06565499366171668, signal :
# 날짜 : 1986-03-31 00:00:00+00:00, 모멘텀 인덱스 : 0.12994182181903358, signal : buy
# 날짜 : 1986-04-30 00:00:00+00:00, 모멘텀 인덱스 : 0.32941261769562113, signal : buy
# 날짜 : 1986-05-30 00:00:00+00:00, 모멘텀 인덱스 : 0.7410076582023379, signal : buy
# 날짜 : 1986-06-30 00:00:00+00:00, 모멘텀 인덱스 : 1.0555590139442232, signal : buy
# 날짜 : 1986-07-31 00:00:00+00:00, 모멘텀 인덱스 : 1.2598453333098059, signal : buy
# 날짜 : 1986-08-29 00:00:00+00:00, 모멘텀 인덱스 : 1.083333722401453, signal : buy
# 날짜 : 1986-09-30 00:00:00+00:00, 모멘텀 인덱스 : 1.3492103016505408, signal : buy
# 날짜 : 1986-10-31 00:00:00+00:00, 모멘텀 인덱스 : 0.7986568853426785, signal : buy
# 날짜 : 1986-11-28 00:00:00+00:00, 모멘텀 인덱스 : 0.7205002662101077, signal : buy
# 날짜 : 1986-12-31 00:00:00+00:00, 모멘텀 인덱스 : 0.818180371234573, signal : buy
# 날짜 : 1987-01-30 00:00:00+00:00, 모멘텀 인덱스 : 0.7513514332005873, signal : buy
# 날짜 : 1987-02-27 00:00:00+00:00, 모멘텀 인덱스 : 1.2199995517931073, signal : buy
# 날짜 : 1987-03-31 00:00:00+00:00, 모멘텀 인덱스 : 1.477878453586524, signal : buy
# 날짜 : 1987-04-30 00:00:00+00:00, 모멘텀 인덱스 : 1.1322301039023577, signal : buy
# 날짜 : 1987-05-29 00:00:00+00:00, 모멘텀 인덱스 : 1.1418910222437577, signal : buy
# 날짜 : 1987-06-30 00:00:00+00:00, 모멘텀 인덱스 : 1.2054350881576683, signal : buy
# 날짜 : 1987-07-31 00:00:00+00:00, 모멘텀 인덱스 : 1.5959374572803284, signal : buy
# 날짜 : 1987-08-31 00:00:00+00:00, 모멘텀 인덱스 : 1.2331165488105875, signal : buy
# 날짜 : 1987-09-30 00:00:00+00:00, 모멘텀 인덱스 : 2.232944009733438, signal : buy
# 날짜 : 1987-10-30 00:00:00+00:00, 모멘텀 인덱스 : 2.272712195220614, signal : buy
# 날짜 : 1987-11-30 00:00:00+00:00, 모멘텀 인덱스 : 0.9366820445930686, signal : buy
# 날짜 : 1987-12-31 00:00:00+00:00, 모멘텀 인덱스 : 0.6377793724764615, signal : buy
# 날짜 : 1988-01-29 00:00:00+00:00, 모멘텀 인덱스 : 0.5210847820353797, signal : buy
# 날짜 : 1988-02-29 00:00:00+00:00, 모멘텀 인덱스 : 0.19164434804444852, signal : buy
# 날짜 : 1988-03-31 00:00:00+00:00, 모멘텀 인덱스 : 0.34264780608987566, signal : buy
# 날짜 : 1988-04-29 00:00:00+00:00, 모멘텀 인덱스 : 0.016516130400549445, signal : buy
# 날짜 : 1988-05-31 00:00:00+00:00, 모멘텀 인덱스 : 0.04364093417657666, signal : buy
# 날짜 : 1988-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.03232567916731077, signal : buy
# 날짜 : 1988-07-29 00:00:00+00:00, 모멘텀 인덱스 : 0.1295657465812523, signal : buy
# 날짜 : 1988-08-31 00:00:00+00:00, 모멘텀 인덱스 : -0.17318468627504224, signal :
# 날짜 : 1988-09-30 00:00:00+00:00, 모멘텀 인덱스 : -0.28856519895827026, signal :
# 날짜 : 1988-10-31 00:00:00+00:00, 모멘텀 인덱스 : 0.1287565598260656, signal : buy
# 날짜 : 1988-11-30 00:00:00+00:00, 모멘텀 인덱스 : 0.17730822183931338, signal : buy
# 날짜 : 1988-12-30 00:00:00+00:00, 모멘텀 인덱스 : -0.09654517912872074, signal :
# 날짜 : 1989-01-31 00:00:00+00:00, 모멘텀 인덱스 : -0.021868112954886, signal :
# 날짜 : 1989-02-28 00:00:00+00:00, 모멘텀 인덱스 : -0.11636815614628693, signal :
# 날짜 : 1989-03-31 00:00:00+00:00, 모멘텀 인덱스 : -0.08532735929674684, signal :
# 날짜 : 1989-04-28 00:00:00+00:00, 모멘텀 인덱스 : -0.12302163825865986, signal :
# 날짜 : 1989-05-31 00:00:00+00:00, 모멘텀 인덱스 : -0.05338213699143346, signal :
# 날짜 : 1989-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.04224488662711745, signal : buy
# 날짜 : 1989-07-31 00:00:00+00:00, 모멘텀 인덱스 : -0.061588153176580174, signal :
# 날짜 : 1989-08-31 00:00:00+00:00, 모멘텀 인덱스 : 0.004443355684758954, signal : buy
# 날짜 : 1989-09-29 00:00:00+00:00, 모멘텀 인덱스 : 0.0391817656862814, signal : buy
# 날짜 : 1989-10-31 00:00:00+00:00, 모멘텀 인덱스 : 0.16361469359350211, signal : buy
# 날짜 : 1989-11-30 00:00:00+00:00, 모멘텀 인덱스 : 0.24494566904117843, signal : buy
# 날짜 : 1989-12-29 00:00:00+00:00, 모멘텀 인덱스 : 0.11017228474706608, signal : buy
# 날짜 : 1990-01-31 00:00:00+00:00, 모멘텀 인덱스 : -0.05705761495765016, signal :
# 날짜 : 1990-02-28 00:00:00+00:00, 모멘텀 인덱스 : -0.05546315287247727, signal :
# 날짜 : 1990-03-30 00:00:00+00:00, 모멘텀 인덱스 : -0.03579531497517463, signal :
# 날짜 : 1990-04-30 00:00:00+00:00, 모멘텀 인덱스 : 0.042669594876927563, signal : buy
# 날짜 : 1990-05-31 00:00:00+00:00, 모멘텀 인덱스 : -0.16872872991063237, signal :
# 날짜 : 1990-06-29 00:00:00+00:00, 모멘텀 인덱스 : 0.010880028002216768, signal : buy
# 날짜 : 1990-07-31 00:00:00+00:00, 모멘텀 인덱스 : 0.1380349952260369, signal : buy
# 날짜 : 1990-08-31 00:00:00+00:00, 모멘텀 인덱스 : -0.04816907422122163, signal :
# 날짜 : 1990-09-28 00:00:00+00:00, 모멘텀 인덱스 : -0.15894638435221842, signal :
# 날짜 : 1990-10-31 00:00:00+00:00, 모멘텀 인덱스 : -0.3691485940694542, signal :
# 날짜 : 1990-11-30 00:00:00+00:00, 모멘텀 인덱스 : -0.2987960451645426, signal :
# 날짜 : 1990-12-31 00:00:00+00:00, 모멘텀 인덱스 : 0.05550988558134762, signal : buy
# 날짜 : 1991-01-31 00:00:00+00:00, 모멘텀 인덱스 : 0.28042406837579326, signal : buy
# 날짜 : 1991-02-28 00:00:00+00:00, 모멘텀 인덱스 : 0.6473317586170582, signal : buy
# 날짜 : 1991-03-28 00:00:00+00:00, 모멘텀 인덱스 : 0.4384356905745934, signal : buy
# 날짜 : 1991-04-30 00:00:00+00:00, 모멘텀 인덱스 : 0.7465027454920234, signal : buy
# 날짜 : 1991-05-31 00:00:00+00:00, 모멘텀 인덱스 : 0.344670063316185, signal : buy
# 날짜 : 1991-06-28 00:00:00+00:00, 모멘텀 인덱스 : 0.06192291382635773, signal : buy
# 날짜 : 1991-07-31 00:00:00+00:00, 모멘텀 인덱스 : -0.0009497875730861693, signal :
# 날짜 : 1991-08-30 00:00:00+00:00, 모멘텀 인덱스 : 0.2600473939729382, signal : buy
# 날짜 : 1991-09-30 00:00:00+00:00, 모멘텀 인덱스 : 0.8464421752641682, signal : buy
# 날짜 : 1991-10-31 00:00:00+00:00, 모멘텀 인덱스 : 0.6263655809645623, signal : buy
# 날짜 : 1991-11-29 00:00:00+00:00, 모멘텀 인덱스 : 0.4110955713527773, signal : buy
# 날짜 : 1991-12-31 00:00:00+00:00, 모멘텀 인덱스 : 0.19129296307705834, signal : buy
# 날짜 : 1992-01-31 00:00:00+00:00, 모멘텀 인덱스 : 0.025284370779798726, signal : buy
# 날짜 : 1992-02-28 00:00:00+00:00, 모멘텀 인덱스 : 0.13920332392089785, signal : buy
# 날짜 : 1992-03-31 00:00:00+00:00, 모멘텀 인덱스 : 0.0017153083959857707, signal : buy
# 날짜 : 1992-04-30 00:00:00+00:00, 모멘텀 인덱스 : 0.06876570708956486, signal : buy
# 날짜 : 1992-05-29 00:00:00+00:00, 모멘텀 인덱스 : 0.2876429211921614, signal : buy
# 날짜 : 1992-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.44919843739869014, signal : buy
# 날짜 : 1992-07-31 00:00:00+00:00, 모멘텀 인덱스 : 0.04674698304512814, signal : buy
# 날짜 : 1992-08-31 00:00:00+00:00, 모멘텀 인덱스 : -0.11235982802616329, signal :
# 날짜 : 1992-09-30 00:00:00+00:00, 모멘텀 인덱스 : -0.062326781539996934, signal :
# 날짜 : 1992-10-30 00:00:00+00:00, 모멘텀 인덱스 : -0.11588589435903385, signal :
# 날짜 : 1992-11-30 00:00:00+00:00, 모멘텀 인덱스 : 0.04130269291103805, signal : buy
# 날짜 : 1992-12-31 00:00:00+00:00, 모멘텀 인덱스 : 0.028867675223065214, signal : buy
# 날짜 : 1993-01-29 00:00:00+00:00, 모멘텀 인덱스 : -0.06915717855504944, signal :
# 날짜 : 1993-02-26 00:00:00+00:00, 모멘텀 인덱스 : -0.11247887382512733, signal :
# 날짜 : 1993-03-31 00:00:00+00:00, 모멘텀 인덱스 : -0.08189411366517707, signal :
# 날짜 : 1993-04-30 00:00:00+00:00, 모멘텀 인덱스 : -0.13569928783494933, signal :
# 날짜 : 1993-05-28 00:00:00+00:00, 모멘텀 인덱스 : -0.13449629462680335, signal :
# 날짜 : 1993-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.19045855675718482, signal : buy
# 날짜 : 1993-07-30 00:00:00+00:00, 모멘텀 인덱스 : -0.1473657479104532, signal :
# 날짜 : 1993-08-31 00:00:00+00:00, 모멘텀 인덱스 : -0.3928657933038002, signal :
# 날짜 : 1993-09-30 00:00:00+00:00, 모멘텀 인덱스 : -0.4063664297564884, signal :
# 날짜 : 1993-10-29 00:00:00+00:00, 모멘텀 인덱스 : -0.5499275585882191, signal :
# 날짜 : 1993-11-30 00:00:00+00:00, 모멘텀 인덱스 : -0.46056070407772187, signal :
# 날짜 : 1993-12-31 00:00:00+00:00, 모멘텀 인덱스 : -0.46629869729510853, signal :
# 날짜 : 1994-01-31 00:00:00+00:00, 모멘텀 인덱스 : -0.5023382444647975, signal :
# 날짜 : 1994-02-28 00:00:00+00:00, 모멘텀 인덱스 : -0.37581454518870827, signal :
# 날짜 : 1994-03-31 00:00:00+00:00, 모멘텀 인덱스 : -0.2815049211066799, signal :
# 날짜 : 1994-04-29 00:00:00+00:00, 모멘텀 인덱스 : -0.3422879071898288, signal :
# 날짜 : 1994-05-31 00:00:00+00:00, 모멘텀 인덱스 : -0.4640272381829461, signal :
# 날짜 : 1994-06-30 00:00:00+00:00, 모멘텀 인덱스 : -0.24790487194138922, signal :
# 날짜 : 1994-07-29 00:00:00+00:00, 모멘텀 인덱스 : -0.030100617231757942, signal :
# 날짜 : 1994-08-31 00:00:00+00:00, 모멘텀 인덱스 : 0.2854551504421263, signal : buy
# 날짜 : 1994-09-30 00:00:00+00:00, 모멘텀 인덱스 : 0.5708856536800069, signal : buy
# 날짜 : 1994-10-31 00:00:00+00:00, 모멘텀 인덱스 : 0.11163302296816369, signal : buy
# 날짜 : 1994-11-30 00:00:00+00:00, 모멘텀 인덱스 : 0.38619789579731867, signal : buy
# 날짜 : 1994-12-30 00:00:00+00:00, 모멘텀 인덱스 : 0.2914704771426362, signal : buy
# 날짜 : 1995-01-31 00:00:00+00:00, 모멘텀 인덱스 : 0.2076394915948172, signal : buy
# 날짜 : 1995-02-28 00:00:00+00:00, 모멘텀 인덱스 : 0.11774640021694016, signal : buy
# 날짜 : 1995-03-31 00:00:00+00:00, 모멘텀 인덱스 : 0.20371403757658157, signal : buy
# 날짜 : 1995-04-28 00:00:00+00:00, 모멘텀 인덱스 : 0.19057315241997563, signal : buy
# 날짜 : 1995-05-31 00:00:00+00:00, 모멘텀 인덱스 : 0.3198043514776536, signal : buy
# 날짜 : 1995-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.5873194006686795, signal : buy
# 날짜 : 1995-07-31 00:00:00+00:00, 모멘텀 인덱스 : 0.39511020062028, signal : buy
# 날짜 : 1995-08-31 00:00:00+00:00, 모멘텀 인덱스 : 0.2541757352618341, signal : buy
# 날짜 : 1995-09-29 00:00:00+00:00, 모멘텀 인덱스 : 0.2908925529150186, signal : buy
# 날짜 : 1995-10-31 00:00:00+00:00, 모멘텀 인덱스 : -0.12771554898855997, signal :
# 날짜 : 1995-11-30 00:00:00+00:00, 모멘텀 인덱스 : -0.01708990773775676, signal :
# 날짜 : 1995-12-29 00:00:00+00:00, 모멘텀 인덱스 : -0.011260021618180294, signal :
# 날짜 : 1996-01-31 00:00:00+00:00, 모멘텀 인덱스 : -0.20150065176103593, signal :
# 날짜 : 1996-02-29 00:00:00+00:00, 모멘텀 인덱스 : -0.29458008426228066, signal :
# 날짜 : 1996-03-29 00:00:00+00:00, 모멘텀 인덱스 : -0.21310596810850602, signal :
# 날짜 : 1996-04-30 00:00:00+00:00, 모멘텀 인덱스 : -0.35228538918622787, signal :
# 날짜 : 1996-05-31 00:00:00+00:00, 모멘텀 인덱스 : -0.4100959329444034, signal :
# 날짜 : 1996-06-28 00:00:00+00:00, 모멘텀 인덱스 : -0.43411782787736464, signal :
# 날짜 : 1996-07-31 00:00:00+00:00, 모멘텀 인덱스 : -0.5305976499233049, signal :
# 날짜 : 1996-08-30 00:00:00+00:00, 모멘텀 인덱스 : -0.4867758716978826, signal :
# 날짜 : 1996-09-30 00:00:00+00:00, 모멘텀 인덱스 : -0.3469621029998958, signal :
# 날짜 : 1996-10-31 00:00:00+00:00, 모멘텀 인덱스 : -0.3870782037618967, signal :
# 날짜 : 1996-11-29 00:00:00+00:00, 모멘텀 인덱스 : -0.39672185297214646, signal :
# 날짜 : 1996-12-31 00:00:00+00:00, 모멘텀 인덱스 : -0.24313697963931347, signal :
# 날짜 : 1997-01-31 00:00:00+00:00, 모멘텀 인덱스 : -0.24434337310365895, signal :
# 날짜 : 1997-02-28 00:00:00+00:00, 모멘텀 인덱스 : -0.39545506319256707, signal :
# 날짜 : 1997-03-31 00:00:00+00:00, 모멘텀 인덱스 : -0.3384221600794294, signal :
# 날짜 : 1997-04-30 00:00:00+00:00, 모멘텀 인덱스 : -0.25128275735462846, signal :
# 날짜 : 1997-05-30 00:00:00+00:00, 모멘텀 인덱스 : -0.34928251324068627, signal :
# 날짜 : 1997-06-30 00:00:00+00:00, 모멘텀 인덱스 : -0.2083339675079373, signal :
# 날짜 : 1997-07-31 00:00:00+00:00, 모멘텀 인덱스 : -0.3522734702001571, signal :
# 날짜 : 1997-08-29 00:00:00+00:00, 모멘텀 인덱스 : -0.278350977456294, signal :
# 날짜 : 1997-09-30 00:00:00+00:00, 모멘텀 인덱스 : -0.019718370727842438, signal :
# 날짜 : 1997-10-31 00:00:00+00:00, 모멘텀 인덱스 : -0.05706543263919284, signal :
# 날짜 : 1997-11-28 00:00:00+00:00, 모멘텀 인덱스 : -0.29404353246519255, signal :
# 날짜 : 1997-12-31 00:00:00+00:00, 모멘텀 인덱스 : -0.1497004337700637, signal :
# 날짜 : 1998-01-30 00:00:00+00:00, 모멘텀 인덱스 : -0.21052520273309983, signal :
# 날짜 : 1998-02-27 00:00:00+00:00, 모멘텀 인덱스 : 0.12692315257371, signal : buy
# 날짜 : 1998-03-31 00:00:00+00:00, 모멘텀 인덱스 : 0.29452015208859095, signal : buy
# 날짜 : 1998-04-30 00:00:00+00:00, 모멘텀 인덱스 : 0.6176470035252644, signal : buy
# 날짜 : 1998-05-29 00:00:00+00:00, 모멘텀 인덱스 : 0.6466176544097573, signal : buy
# 날짜 : 1998-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.8684224692487821, signal : buy
# 날짜 : 1998-07-31 00:00:00+00:00, 모멘텀 인덱스 : 0.6392867449106696, signal : buy
# 날짜 : 1998-08-31 00:00:00+00:00, 모멘텀 인덱스 : 0.5919539976516819, signal : buy
# 날짜 : 1998-09-30 00:00:00+00:00, 모멘텀 인덱스 : 0.43804188754824747, signal : buy
# 날짜 : 1998-10-30 00:00:00+00:00, 모멘텀 인덱스 : 1.238539479141449, signal : buy
# 날짜 : 1998-11-30 00:00:00+00:00, 모멘텀 인덱스 : 1.0915493211366014, signal : buy
# 날짜 : 1998-12-31 00:00:00+00:00, 모멘텀 인덱스 : 1.4333319533702356, signal : buy
# 날짜 : 1999-01-29 00:00:00+00:00, 모멘텀 인덱스 : 1.2354945290859933, signal : buy
# 날짜 : 1999-02-26 00:00:00+00:00, 모멘텀 인덱스 : 0.7433873278594711, signal : buy
# 날짜 : 1999-03-31 00:00:00+00:00, 모멘텀 인덱스 : 0.2659085573219462, signal : buy
# 날짜 : 1999-04-30 00:00:00+00:00, 모멘텀 인덱스 : 0.3127855454041275, signal : buy
# 날짜 : 1999-05-28 00:00:00+00:00, 모멘텀 인덱스 : 0.7276995474244008, signal : buy
# 날짜 : 1999-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.5359466273888933, signal : buy
# 날짜 : 1999-07-30 00:00:00+00:00, 모멘텀 인덱스 : 0.3375451396837821, signal : buy
# 날짜 : 1999-08-31 00:00:00+00:00, 모멘텀 인덱스 : 0.7855703680018367, signal : buy
# 날짜 : 1999-09-30 00:00:00+00:00, 모멘텀 인덱스 : 0.7114741014480115, signal : buy
# 날짜 : 1999-10-29 00:00:00+00:00, 모멘텀 인덱스 : 0.7053871604559883, signal : buy
# 날짜 : 1999-11-30 00:00:00+00:00, 모멘텀 인덱스 : 1.508805359374953, signal : buy
# 날짜 : 1999-12-31 00:00:00+00:00, 모멘텀 인덱스 : 1.3908387088714727, signal : buy
# 날짜 : 2000-01-31 00:00:00+00:00, 모멘텀 인덱스 : 1.4962056396634233, signal : buy
# 날짜 : 2000-02-29 00:00:00+00:00, 모멘텀 인덱스 : 1.980251016829329, signal : buy
# 날짜 : 2000-03-31 00:00:00+00:00, 모멘텀 인덱스 : 2.1895642707725584, signal : buy
# 날짜 : 2000-04-28 00:00:00+00:00, 모멘텀 인덱스 : 1.952444811008407, signal : buy
# 날짜 : 2000-05-31 00:00:00+00:00, 모멘텀 인덱스 : 1.8156048432726042, signal : buy
# 날짜 : 2000-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.8137653833625034, signal : buy
# 날짜 : 2000-07-31 00:00:00+00:00, 모멘텀 인덱스 : 0.881032967701536, signal : buy
# 날짜 : 2000-08-31 00:00:00+00:00, 모멘텀 인덱스 : 0.557471613453117, signal : buy
# 날짜 : 2000-09-29 00:00:00+00:00, 모멘텀 인덱스 : 0.9249748718096287, signal : buy
# 날짜 : 2000-10-31 00:00:00+00:00, 모멘텀 인덱스 : -0.357254180643365, signal :
# 날짜 : 2000-11-30 00:00:00+00:00, 모멘텀 인덱스 : -0.600255503330785, signal :
# 날짜 : 2000-12-29 00:00:00+00:00, 모멘텀 인덱스 : -0.679027179677853, signal :
# 날짜 : 2001-01-31 00:00:00+00:00, 모멘텀 인덱스 : -0.7132529266789895, signal :
# 날짜 : 2001-02-28 00:00:00+00:00, 모멘텀 인덱스 : -0.622682673013883, signal :
# 날짜 : 2001-03-30 00:00:00+00:00, 모멘텀 인덱스 : -0.7312472288457972, signal :
# 날짜 : 2001-04-30 00:00:00+00:00, 모멘텀 인덱스 : -0.644211768912852, signal :
# 날짜 : 2001-05-31 00:00:00+00:00, 모멘텀 인덱스 : -0.3930952844805805, signal :
# 날짜 : 2001-06-29 00:00:00+00:00, 모멘텀 인덱스 : -0.6190929817580877, signal :
# 날짜 : 2001-07-31 00:00:00+00:00, 모멘텀 인덱스 : -0.5424353895372755, signal :
# 날짜 : 2001-08-31 00:00:00+00:00, 모멘텀 인덱스 : -0.6916513268956561, signal :
# 날짜 : 2001-09-28 00:00:00+00:00, 모멘텀 인덱스 : -0.279611461283908, signal :
# 날짜 : 2001-10-31 00:00:00+00:00, 모멘텀 인덱스 : -0.20715647654510194, signal :
# 날짜 : 2001-11-30 00:00:00+00:00, 모멘텀 인덱스 : 0.06424249585699449, signal : buy
# 날짜 : 2001-12-31 00:00:00+00:00, 모멘텀 인덱스 : 0.43193296812032056, signal : buy
# 날짜 : 2002-01-31 00:00:00+00:00, 모멘텀 인덱스 : 0.012716974885304877, signal : buy
# 날짜 : 2002-02-28 00:00:00+00:00, 모멘텀 인덱스 : 0.3545210627987174, signal : buy
# 날짜 : 2002-03-28 00:00:00+00:00, 모멘텀 인덱스 : -0.016764699706081965, signal :
# 날짜 : 2002-04-30 00:00:00+00:00, 모멘텀 인덱스 : -0.0714006717245591, signal :
# 날짜 : 2002-05-31 00:00:00+00:00, 모멘텀 인덱스 : 0.2165408197433074, signal : buy
# 날짜 : 2002-06-28 00:00:00+00:00, 모멘텀 인덱스 : 0.002150760842817734, signal : buy
# 날짜 : 2002-07-31 00:00:00+00:00, 모멘텀 인덱스 : -0.05694548868983018, signal :
# 날짜 : 2002-08-30 00:00:00+00:00, 모멘텀 인덱스 : -0.17735856208846257, signal :
# 날짜 : 2002-09-30 00:00:00+00:00, 모멘텀 인덱스 : -0.04900078824129461, signal :
# 날짜 : 2002-10-31 00:00:00+00:00, 모멘텀 인덱스 : -0.1742597090802528, signal :
# 날짜 : 2002-11-29 00:00:00+00:00, 모멘텀 인덱스 : -0.2455402696246144, signal :
# 날짜 : 2002-12-31 00:00:00+00:00, 모멘텀 인덱스 : -0.29223780612393824, signal :
# 날짜 : 2003-01-31 00:00:00+00:00, 모멘텀 인덱스 : -0.4203076382015456, signal :
# 날짜 : 2003-02-28 00:00:00+00:00, 모멘텀 인덱스 : -0.33824847460498064, signal :
# 날짜 : 2003-03-31 00:00:00+00:00, 모멘텀 인덱스 : -0.3658642306640605, signal :
# 날짜 : 2003-04-30 00:00:00+00:00, 모멘텀 인덱스 : -0.41738797188835675, signal :
# 날짜 : 2003-05-30 00:00:00+00:00, 모멘텀 인덱스 : -0.3896998757855995, signal :
# 날짜 : 2003-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.012979774567506208, signal : buy
# 날짜 : 2003-07-31 00:00:00+00:00, 모멘텀 인덱스 : 0.24901662212317444, signal : buy
# 날짜 : 2003-08-29 00:00:00+00:00, 모멘텀 인덱스 : 0.42915232420941773, signal : buy
# 날짜 : 2003-09-30 00:00:00+00:00, 모멘텀 인덱스 : 0.5593100970334481, signal : buy
# 날짜 : 2003-10-31 00:00:00+00:00, 모멘텀 인덱스 : 0.28935931962019046, signal : buy
# 날짜 : 2003-11-28 00:00:00+00:00, 모멘텀 인덱스 : 0.4767741463198365, signal : buy
# 날짜 : 2003-12-31 00:00:00+00:00, 모멘텀 인덱스 : 0.4591770959028769, signal : buy
# 날짜 : 2004-01-30 00:00:00+00:00, 모멘텀 인덱스 : 0.48816100499022874, signal : buy
# 날짜 : 2004-02-27 00:00:00+00:00, 모멘텀 인덱스 : 0.5029982070381209, signal : buy
# 날짜 : 2004-03-31 00:00:00+00:00, 모멘텀 인덱스 : 0.6916552986079167, signal : buy
# 날짜 : 2004-04-30 00:00:00+00:00, 모멘텀 인덱스 : 0.9015481093959845, signal : buy
# 날짜 : 2004-05-28 00:00:00+00:00, 모멘텀 인덱스 : 0.4362122660911649, signal : buy
# 날짜 : 2004-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.4721934581029994, signal : buy
# 날짜 : 2004-07-30 00:00:00+00:00, 모멘텀 인덱스 : 0.5436439434774598, signal : buy
# 날짜 : 2004-08-31 00:00:00+00:00, 모멘텀 인덱스 : 0.4303403975298048, signal : buy
# 날짜 : 2004-09-30 00:00:00+00:00, 모멘텀 인덱스 : 0.6645751752957718, signal : buy
# 날짜 : 2004-10-29 00:00:00+00:00, 모멘텀 인덱스 : 0.6928793896839156, signal : buy
# 날짜 : 2004-11-30 00:00:00+00:00, 모멘텀 인덱스 : 1.5059782392701995, signal : buy
# 날짜 : 2004-12-31 00:00:00+00:00, 모멘텀 인덱스 : 2.137575194661067, signal : buy
# 날짜 : 2005-01-31 00:00:00+00:00, 모멘텀 인덱스 : 1.8546106776570532, signal : buy
# 날짜 : 2005-02-28 00:00:00+00:00, 모멘텀 인덱스 : 2.214883100674925, signal : buy
# 날짜 : 2005-03-31 00:00:00+00:00, 모멘텀 인덱스 : 2.3180465818906515, signal : buy
# 날짜 : 2005-04-29 00:00:00+00:00, 모멘텀 인덱스 : 2.232737912586903, signal : buy
# 날짜 : 2005-05-31 00:00:00+00:00, 모멘텀 인덱스 : 1.5702059387873306, signal : buy
# 날짜 : 2005-06-30 00:00:00+00:00, 모멘텀 인덱스 : 1.4437612897332306, signal : buy
# 날짜 : 2005-07-29 00:00:00+00:00, 모멘텀 인덱스 : 1.2764378020257685, signal : buy
# 날짜 : 2005-08-31 00:00:00+00:00, 모멘텀 인덱스 : 1.4731808577677277, signal : buy
# 날짜 : 2005-09-30 00:00:00+00:00, 모멘텀 인덱스 : 1.4201292271323362, signal : buy
# 날짜 : 2005-10-31 00:00:00+00:00, 모멘텀 인덱스 : 1.0461829323189944, signal : buy
# 날짜 : 2005-11-30 00:00:00+00:00, 모멘텀 인덱스 : 0.717822418165138, signal : buy
# 날짜 : 2005-12-30 00:00:00+00:00, 모멘텀 인덱스 : 1.106210732519814, signal : buy
# 날짜 : 2006-01-31 00:00:00+00:00, 모멘텀 인덱스 : 0.8697003804316878, signal : buy
# 날짜 : 2006-02-28 00:00:00+00:00, 모멘텀 인덱스 : 0.6832367460828506, signal : buy
# 날짜 : 2006-03-31 00:00:00+00:00, 모멘텀 인덱스 : 0.6436286584050432, signal : buy
# 날짜 : 2006-04-28 00:00:00+00:00, 모멘텀 인덱스 : 0.7393228728676493, signal : buy
# 날짜 : 2006-05-31 00:00:00+00:00, 모멘텀 인덱스 : 0.7703722684287797, signal : buy
# 날짜 : 2006-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.6237437484546835, signal : buy
# 날짜 : 2006-07-31 00:00:00+00:00, 모멘텀 인덱스 : 0.34279028462656824, signal : buy
# 날짜 : 2006-08-31 00:00:00+00:00, 모멘텀 인덱스 : 0.44934947904302946, signal : buy
# 날짜 : 2006-09-29 00:00:00+00:00, 모멘텀 인덱스 : 0.265622179683181, signal : buy
# 날짜 : 2006-10-31 00:00:00+00:00, 모멘텀 인덱스 : 0.3366906634532203, signal : buy
# 날짜 : 2006-11-30 00:00:00+00:00, 모멘텀 인덱스 : 0.19551776860687187, signal : buy
# 날짜 : 2006-12-29 00:00:00+00:00, 모멘텀 인덱스 : 0.27500398752225097, signal : buy
# 날짜 : 2007-01-31 00:00:00+00:00, 모멘텀 인덱스 : 0.12355983178994046, signal : buy
# 날짜 : 2007-02-28 00:00:00+00:00, 모멘텀 인덱스 : 0.2517154304623863, signal : buy
# 날짜 : 2007-03-30 00:00:00+00:00, 모멘텀 인덱스 : 0.34901209266961364, signal : buy
# 날짜 : 2007-04-30 00:00:00+00:00, 모멘텀 인덱스 : 0.3199315071758766, signal : buy
# 날짜 : 2007-05-31 00:00:00+00:00, 모멘텀 인덱스 : 0.6697341202991374, signal : buy
# 날짜 : 2007-06-29 00:00:00+00:00, 모멘텀 인덱스 : 1.1161164029875112, signal : buy
# 날짜 : 2007-07-31 00:00:00+00:00, 모멘텀 인덱스 : 0.7957624876690039, signal : buy
# 날짜 : 2007-08-31 00:00:00+00:00, 모멘텀 인덱스 : 0.941930875698147, signal : buy
# 날짜 : 2007-09-28 00:00:00+00:00, 모멘텀 인덱스 : 0.7989086776300607, signal : buy
# 날짜 : 2007-10-31 00:00:00+00:00, 모멘텀 인덱스 : 0.8928218612150289, signal : buy
# 날짜 : 2007-11-30 00:00:00+00:00, 모멘텀 인덱스 : 1.0723327354475103, signal : buy
# 날짜 : 2007-12-31 00:00:00+00:00, 모멘텀 인덱스 : 1.1478077693251492, signal : buy
# 날짜 : 2008-01-31 00:00:00+00:00, 모멘텀 인덱스 : 1.3105100443654214, signal : buy
# 날짜 : 2008-02-29 00:00:00+00:00, 모멘텀 인덱스 : 0.5998110247821025, signal : buy
# 날짜 : 2008-03-31 00:00:00+00:00, 모멘텀 인덱스 : 0.3456033959767122, signal : buy
# 날짜 : 2008-04-30 00:00:00+00:00, 모멘텀 인덱스 : 0.43787551523566703, signal : buy
# 날짜 : 2008-05-30 00:00:00+00:00, 모멘텀 인덱스 : 0.4353493730881468, signal : buy
# 날짜 : 2008-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.5466235647329767, signal : buy
# 날짜 : 2008-07-31 00:00:00+00:00, 모멘텀 인덱스 : 0.27079509152925896, signal : buy
# 날짜 : 2008-08-29 00:00:00+00:00, 모멘텀 인덱스 : 0.14781951693205175, signal : buy
# 날짜 : 2008-09-30 00:00:00+00:00, 모멘텀 인덱스 : 0.10464606635568541, signal : buy
# 날짜 : 2008-10-31 00:00:00+00:00, 모멘텀 인덱스 : -0.40163207669362155, signal :
# 날짜 : 2008-11-28 00:00:00+00:00, 모멘텀 인덱스 : -0.40956002534786107, signal :
# 날짜 : 2008-12-31 00:00:00+00:00, 모멘텀 인덱스 : -0.5321587480442023, signal :
# 날짜 : 2009-01-30 00:00:00+00:00, 모멘텀 인덱스 : -0.3694593764793104, signal :
# 날짜 : 2009-02-27 00:00:00+00:00, 모멘텀 인덱스 : -0.2790752477473778, signal :
# 날짜 : 2009-03-31 00:00:00+00:00, 모멘텀 인덱스 : -0.3776306554048354, signal :
# 날짜 : 2009-04-30 00:00:00+00:00, 모멘텀 인덱스 : -0.3956883175180338, signal :
# 날짜 : 2009-05-29 00:00:00+00:00, 모멘텀 인덱스 : -0.33335083152241185, signal :
# 날짜 : 2009-06-30 00:00:00+00:00, 모멘텀 인덱스 : -0.1889035602804976, signal :
# 날짜 : 2009-07-31 00:00:00+00:00, 모멘텀 인덱스 : -0.10393219989300284, signal :
# 날짜 : 2009-08-31 00:00:00+00:00, 모멘텀 인덱스 : -0.03621811790125995, signal :
# 날짜 : 2009-09-30 00:00:00+00:00, 모멘텀 인덱스 : 0.4799402905286332, signal : buy
# 날짜 : 2009-10-30 00:00:00+00:00, 모멘텀 인덱스 : 0.7227440322060164, signal : buy
# 날짜 : 2009-11-30 00:00:00+00:00, 모멘텀 인덱스 : 1.0340996218798533, signal : buy
# 날짜 : 2009-12-31 00:00:00+00:00, 모멘텀 인덱스 : 1.3422377450978096, signal : buy
# 날짜 : 2010-01-29 00:00:00+00:00, 모멘텀 인덱스 : 1.338067378873177, signal : buy
# 날짜 : 2010-02-26 00:00:00+00:00, 모멘텀 인덱스 : 1.1504870903585878, signal : buy
# 날짜 : 2010-03-31 00:00:00+00:00, 모멘텀 인덱스 : 0.9465371589200071, signal : buy
# 날짜 : 2010-04-30 00:00:00+00:00, 모멘텀 인덱스 : 0.8675996593182504, signal : buy
# 날짜 : 2010-05-28 00:00:00+00:00, 모멘텀 인덱스 : 0.9224656058655893, signal : buy
# 날짜 : 2010-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.8035523759459491, signal : buy
# 날짜 : 2010-07-30 00:00:00+00:00, 모멘텀 인덱스 : 0.5394459942740937, signal : buy
# 날짜 : 2010-08-31 00:00:00+00:00, 모멘텀 인덱스 : 0.5293378740562196, signal : buy
# 날짜 : 2010-09-30 00:00:00+00:00, 모멘텀 인덱스 : 0.3115730863758013, signal : buy
# 날짜 : 2010-10-29 00:00:00+00:00, 모멘텀 인덱스 : 0.5053051244562894, signal : buy
# 날짜 : 2010-11-30 00:00:00+00:00, 모멘텀 인덱스 : 0.505577053958894, signal : buy
# 날짜 : 2010-12-31 00:00:00+00:00, 모멘텀 인덱스 : 0.476534124094393, signal : buy
# 날짜 : 2011-01-31 00:00:00+00:00, 모멘텀 인덱스 : 0.6794752346651864, signal : buy
# 날짜 : 2011-02-28 00:00:00+00:00, 모멘텀 인덱스 : 0.658293625692578, signal : buy
# 날짜 : 2011-03-31 00:00:00+00:00, 모멘텀 인덱스 : 0.5030211099759925, signal : buy
# 날짜 : 2011-04-29 00:00:00+00:00, 모멘텀 인덱스 : 0.33482702009231446, signal : buy
# 날짜 : 2011-05-31 00:00:00+00:00, 모멘텀 인덱스 : 0.36301015293070793, signal : buy
# 날짜 : 2011-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.38285678233590814, signal : buy
# 날짜 : 2011-07-29 00:00:00+00:00, 모멘텀 인덱스 : 0.30483988956845187, signal : buy
# 날짜 : 2011-08-31 00:00:00+00:00, 모멘텀 인덱스 : 0.6062518045410534, signal : buy
# 날짜 : 2011-09-30 00:00:00+00:00, 모멘텀 인덱스 : 0.35622919486492766, signal : buy
# 날짜 : 2011-10-31 00:00:00+00:00, 모멘텀 인덱스 : 0.26692851222323943, signal : buy
# 날짜 : 2011-11-30 00:00:00+00:00, 모멘텀 인덱스 : 0.3009159927815199, signal : buy
# 날짜 : 2011-12-30 00:00:00+00:00, 모멘텀 인덱스 : 0.18489574017858956, signal : buy
# 날짜 : 2012-01-31 00:00:00+00:00, 모멘텀 인덱스 : 0.19356343558172417, signal : buy
# 날짜 : 2012-02-29 00:00:00+00:00, 모멘텀 인덱스 : 0.29237533171254504, signal : buy
# 날짜 : 2012-03-30 00:00:00+00:00, 모멘텀 인덱스 : 0.5564548082020344, signal : buy
# 날짜 : 2012-04-30 00:00:00+00:00, 모멘텀 인덱스 : 0.7123635306861884, signal : buy
# 날짜 : 2012-05-31 00:00:00+00:00, 모멘텀 인덱스 : 0.6789236627486843, signal : buy
# 날짜 : 2012-06-29 00:00:00+00:00, 모멘텀 인덱스 : 0.7211248927141305, signal : buy
# 날짜 : 2012-07-31 00:00:00+00:00, 모멘텀 인덱스 : 0.4955952329525555, signal : buy
# 날짜 : 2012-08-31 00:00:00+00:00, 모멘텀 인덱스 : 0.5870903537035712, signal : buy
# 날짜 : 2012-09-28 00:00:00+00:00, 모멘텀 인덱스 : 0.7520618465751536, signal : buy
# 날짜 : 2012-10-31 00:00:00+00:00, 모멘텀 인덱스 : 0.6551310551902414, signal : buy
# 날짜 : 2012-11-30 00:00:00+00:00, 모멘텀 인덱스 : 0.5643015443648645, signal : buy
# 날짜 : 2012-12-31 00:00:00+00:00, 모멘텀 인덱스 : 0.45796937290937234, signal : buy
# 날짜 : 2013-01-31 00:00:00+00:00, 모멘텀 인덱스 : 0.17616561400226471, signal : buy
# 날짜 : 2013-02-28 00:00:00+00:00, 모멘텀 인덱스 : -0.1528373309174741, signal :
# 날짜 : 2013-03-28 00:00:00+00:00, 모멘텀 인덱스 : -0.2529141081318558, signal :
# 날짜 : 2013-04-30 00:00:00+00:00, 모멘텀 인덱스 : -0.23080640012728482, signal :
# 날짜 : 2013-05-31 00:00:00+00:00, 모멘텀 인덱스 : -0.2222743037464756, signal :
# 날짜 : 2013-06-28 00:00:00+00:00, 모멘텀 인덱스 : -0.21337530935880522, signal :
# 날짜 : 2013-07-31 00:00:00+00:00, 모멘텀 인덱스 : -0.3368161059429585, signal :
# 날짜 : 2013-08-30 00:00:00+00:00, 모멘텀 인덱스 : -0.3081102919863469, signal :
# 날짜 : 2013-09-30 00:00:00+00:00, 모멘텀 인덱스 : -0.25224337454693546, signal :
# 날짜 : 2013-10-31 00:00:00+00:00, 모멘텀 인덱스 : -0.1800899984556762, signal :
# 날짜 : 2013-11-29 00:00:00+00:00, 모멘텀 인덱스 : -0.08980221487329576, signal :
# 날짜 : 2013-12-31 00:00:00+00:00, 모멘텀 인덱스 : 0.07115949707083247, signal : buy
# 날짜 : 2014-01-31 00:00:00+00:00, 모멘텀 인덱스 : 0.2626255215971032, signal : buy
# 날짜 : 2014-02-28 00:00:00+00:00, 모멘텀 인덱스 : 0.1558717348467733, signal : buy
# 날짜 : 2014-03-31 00:00:00+00:00, 모멘텀 인덱스 : 0.21886818189483503, signal : buy
# 날짜 : 2014-04-30 00:00:00+00:00, 모멘텀 인덱스 : 0.24285131531145998, signal : buy
# 날짜 : 2014-05-30 00:00:00+00:00, 모멘텀 인덱스 : 0.3364249348303827, signal : buy
# 날짜 : 2014-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.6350261764952652, signal : buy
# 날짜 : 2014-07-31 00:00:00+00:00, 모멘텀 인덱스 : 0.47232501654132086, signal : buy
# 날짜 : 2014-08-29 00:00:00+00:00, 모멘텀 인덱스 : 0.3975575656000645, signal : buy
# 날짜 : 2014-09-30 00:00:00+00:00, 모멘텀 인덱스 : 0.538951724785456, signal : buy
# 날짜 : 2014-10-31 00:00:00+00:00, 모멘텀 인덱스 : 0.3796986332396264, signal : buy
# 날짜 : 2014-11-28 00:00:00+00:00, 모멘텀 인덱스 : 0.38215850991145106, signal : buy
# 날짜 : 2014-12-31 00:00:00+00:00, 모멘텀 인덱스 : 0.5151508061195047, signal : buy
# 날짜 : 2015-01-30 00:00:00+00:00, 모멘텀 인덱스 : 0.5759501928967723, signal : buy
# 날짜 : 2015-02-27 00:00:00+00:00, 모멘텀 인덱스 : 0.5817816003162453, signal : buy
# 날짜 : 2015-03-31 00:00:00+00:00, 모멘텀 인덱스 : 0.7071260676885947, signal : buy
# 날짜 : 2015-04-30 00:00:00+00:00, 모멘텀 인덱스 : 0.5040710528779451, signal : buy
# 날짜 : 2015-05-29 00:00:00+00:00, 모멘텀 인덱스 : 0.4023932792957723, signal : buy
# 날짜 : 2015-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.42651567763024345, signal : buy
# 날짜 : 2015-07-31 00:00:00+00:00, 모멘텀 인덱스 : 0.33505295718568817, signal : buy
# 날짜 : 2015-08-31 00:00:00+00:00, 모멘텀 인덱스 : 0.19822106399610617, signal : buy
# 날짜 : 2015-09-30 00:00:00+00:00, 모멘텀 인덱스 : 0.1383387385742063, signal : buy
# 날짜 : 2015-10-30 00:00:00+00:00, 모멘텀 인덱스 : 0.03875517070544454, signal : buy
# 날짜 : 2015-11-30 00:00:00+00:00, 모멘텀 인덱스 : 0.017557196047349732, signal : buy
# 날짜 : 2015-12-31 00:00:00+00:00, 모멘텀 인덱스 : 0.09001299441193078, signal : buy
# 날짜 : 2016-01-29 00:00:00+00:00, 모멘텀 인덱스 : -0.08626275020687224, signal :
# 날짜 : 2016-02-29 00:00:00+00:00, 모멘텀 인덱스 : -0.23237337964533022, signal :
# 날짜 : 2016-03-31 00:00:00+00:00, 모멘텀 인덱스 : -0.20853200612961076, signal :
# 날짜 : 2016-04-29 00:00:00+00:00, 모멘텀 인덱스 : -0.11298144283504852, signal :
# 날짜 : 2016-05-31 00:00:00+00:00, 모멘텀 인덱스 : -0.2701830299848662, signal :
# 날짜 : 2016-06-30 00:00:00+00:00, 모멘텀 인덱스 : -0.1875572169116292, signal :
# 날짜 : 2016-07-29 00:00:00+00:00, 모멘텀 인덱스 : -0.19573356615599813, signal :
# 날짜 : 2016-08-31 00:00:00+00:00, 모멘텀 인덱스 : -0.06115116195061032, signal :
# 날짜 : 2016-09-30 00:00:00+00:00, 모멘텀 인덱스 : -0.01751127153000498, signal :
# 날짜 : 2016-10-31 00:00:00+00:00, 모멘텀 인덱스 : -0.03374803530256254, signal :
# 날짜 : 2016-11-30 00:00:00+00:00, 모멘텀 인덱스 : -0.023894397905245945, signal :
# 날짜 : 2016-12-30 00:00:00+00:00, 모멘텀 인덱스 : 0.07333238213265458, signal : buy
# 날짜 : 2017-01-31 00:00:00+00:00, 모멘텀 인덱스 : 0.2163233480700817, signal : buy
# 날짜 : 2017-02-28 00:00:00+00:00, 모멘텀 인덱스 : 0.27604140176094116, signal : buy
# 날짜 : 2017-03-31 00:00:00+00:00, 모멘텀 인덱스 : 0.2834753793867473, signal : buy
# 날짜 : 2017-04-28 00:00:00+00:00, 모멘텀 인덱스 : 0.5649348122185209, signal : buy
# 날짜 : 2017-05-31 00:00:00+00:00, 모멘텀 인덱스 : 0.4600352197131572, signal : buy
# 날짜 : 2017-06-30 00:00:00+00:00, 모멘텀 인덱스 : 0.6285078687331069, signal : buy
# 날짜 : 2017-07-31 00:00:00+00:00, 모멘텀 인덱스 : 0.4084828430840721, signal : buy
# 날짜 : 2017-08-31 00:00:00+00:00, 모멘텀 인덱스 : 0.4209375166157312, signal : buy
# 날짜 : 2017-09-29 00:00:00+00:00, 모멘텀 인덱스 : 0.4762745818037266, signal : buy
# 날짜 : 2017-10-31 00:00:00+00:00, 모멘텀 인덱스 : 0.381351045361914, signal : buy
# 날짜 : 2017-11-30 00:00:00+00:00, 모멘텀 인덱스 : 0.5485260478203329, signal : buy
# 날짜 : 2017-12-29 00:00:00+00:00, 모멘텀 인덱스 : 0.5076284001571167, signal : buy
# 날짜 : 2018-01-31 00:00:00+00:00, 모멘텀 인덱스 : 0.41698708697016107, signal : buy
# 날짜 : 2018-02-28 00:00:00+00:00, 모멘텀 인덱스 : 0.2364992689064056, signal : buy
# 날짜 : 2018-03-29 00:00:00+00:00, 모멘텀 인덱스 : 0.25948613057306336, signal : buy
# 날짜 : 2018-04-30 00:00:00+00:00, 모멘텀 인덱스 : 0.18645446851327097, signal : buy
# 날짜 : 2018-05-31 00:00:00+00:00, 모멘텀 인덱스 : 0.09442424222463064, signal : buy
# 날짜 : 2018-06-29 00:00:00+00:00, 모멘텀 인덱스 : 0.31769802905519917, signal : buy
# 날짜 : 2018-07-31 00:00:00+00:00, 모멘텀 인덱스 : 0.2639514697838219, signal : buy
# 날짜 : 2018-08-31 00:00:00+00:00, 모멘텀 인덱스 : 0.17373244176083924, signal : buy
# 날짜 : 2018-09-28 00:00:00+00:00, 모멘텀 인덱스 : 0.49929797914159657, signal : buy
# 날짜 : 2018-10-31 00:00:00+00:00, 모멘텀 인덱스 : 0.35561537212080685, signal : buy
# 날짜 : 2018-11-30 00:00:00+00:00, 모멘텀 인덱스 : 0.28817791120237346, signal : buy
# 날짜 : 2018-12-31 00:00:00+00:00, 모멘텀 인덱스 : 0.07109289329323887, signal : buy
# 날짜 : 2019-01-31 00:00:00+00:00, 모멘텀 인덱스 : -0.043730566283663785, signal :
# 날짜 : 2019-02-28 00:00:00+00:00, 모멘텀 인덱스 : -0.05539633847700276, signal :
# 날짜 : 2019-03-29 00:00:00+00:00, 모멘텀 인덱스 : 0.04772077271861508, signal : buy
# 날짜 : 2019-04-30 00:00:00+00:00, 모멘텀 인덱스 : 0.16690313321985872, signal : buy
# 날짜 : 2019-05-31 00:00:00+00:00, 모멘텀 인덱스 : 0.08601205591745198, signal : buy
# 날짜 : 2019-06-24 00:00:00+00:00, 모멘텀 인덱스 : -0.03984150820660981, signal :

# %%
df['trade'].value_counts()
# Out:
# trade
# buy    6092
#        3623
# Name: count, dtype: int64

# %%
df['rtn'] = 1

for idx in df.index:
    if df.shift().loc[idx,'trade'] =='' and df.loc[idx,'trade'] =='buy':
        # 매수 가격
        buy = df.loc[idx,'Adj Close']
    elif df.shift().loc[idx,'trade'] =='buy' and df.loc[idx,'trade'] =='':
        # 매도 가격
        sell = df.loc[idx,'Adj Close']
        rtn = sell / buy 
        df.loc[idx,'rtn'] = rtn
        
df['acc_rtn'] = df['rtn'].cumprod()
df[['rtn','acc_rtn']]
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_33940\2037418445.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.390411905109097' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[idx,'rtn'] = rtn
#                                 rtn    acc_rtn
# Date
# 1980-12-12 00:00:00+00:00  1.000000   1.000000
# 1980-12-15 00:00:00+00:00  1.000000   1.000000
# 1980-12-16 00:00:00+00:00  1.000000   1.000000
# 1980-12-17 00:00:00+00:00  1.000000   1.000000
# 1980-12-18 00:00:00+00:00  1.000000   1.000000
# ...                             ...        ...
# 2019-06-18 00:00:00+00:00  1.000000  71.506486
# 2019-06-19 00:00:00+00:00  1.000000  71.506486
# 2019-06-20 00:00:00+00:00  1.000000  71.506486
# 2019-06-21 00:00:00+00:00  1.000000  71.506486
# 2019-06-24 00:00:00+00:00  1.052577  75.266081
#
# [9715 rows x 2 columns]

# %% [markdown]
# #### 절대 모멘텀 함수 만들기
# 1. create_ym 함수
#     - 매개변수 2개
#         - 데이터 프레임 (_df)
#         - 기준 컬럼 (_col = 'Adj Close')
#     - 데이터 프레임의 복사본을 생성해서 작업
#     - 컬럼에 Date가 있다면 Date를 인덱스로 설정
#     - 인덱스를 시계열 데이터로 변경
#     - 데이터 중 결측치, 양의 무한, 음의 무한이 있으면 제외 flag, ~flag
#     - 기준 컬럼 제외하고 모두 삭제
#     - 'STD-YM' 파생변수 생성 index에서 '년-월'을 추출하여 대입
#     - 위에서 작업된 데이터프레임을 되돌려준다.

# %%
def create_ym(_df,
              _col='Adj Close'):
    df = _df.copy()
    
    # 인덱스 변경
    if 'Date' in df.index:
        df.set_index('Date')
    
    # 인덱스 시계열로 변경
    df.index = pd.to_datetime(df.index)
    
    # 데이터 중 결측, 양의 무한, 음의 무한 제외
    flag = df.isin([np.nan,np.inf,-np.inf]).any(axis=1)
    
    # 기준 컬럼 제외하고 삭제
    df = df.loc[~flag,[_col]]
    
    # 'STD-YM' 파생 생성 index에서 년 월 추출 대입
    df['STD-YM'] = df.index.strftime('%Y-%m')
    
    return df

# %%
# 데이터 로드
amzn_df = pd.read_csv('../csv/AMZN.csv', index_col='Date')

# %%
df_ym = create_ym(amzn_df)

# %% [markdown]
# 2. 두번째 함수 생성(create_month)
#     - 매개변수 5개
#         - STD-YM 컬럼이 존재하는 데이터프레임 _df
#         - 시작 시간 (_start = '2010-01-01')
#         - 종료 시간 (_end = datetime.now())
#         - momentum기간 (_momentum = 12)
#         - 기준시점[월말shift(-1), 월초shift(1)] :1인 경우는 월말, 0인 경우 월초
#     - _select가 1이라면
#         - _df에서 월말의 데이터들을 result에 대입
#     - 0이라면
#         - _df에서 월 초의 데이터들을 result에 대입
#     - 둘 다 아니라면
#         - return으로 함수 종료, print를 이용해서 select타입이 잘못됐다 출력
#     - 기준이 되는 컬럼의 이름[_df에서 첫번째 컬럼의 이름]을 변수에 저장
#     - 전월의 기준이 되는 컬럼의 값을 BF1 컬럼에 대입
#     - _momentum 개월 전 데이터를 BF2 컬럼에 대입
#     - 시작 시간과 종료 시간을 기준으로 인덱스 필터링
#     - 결과(result)를 되돌려준다. : ym_df는 변경이 되지 않은 상태

# %%
def create_month(_df,
               _start = '2010-01-01',
               _end = datetime.now(),
               _momentum = 12,
               _select = 1):
    if _select ==1:
        # 월말 데이터 조건식
        flag = _df['STD-YM'] != _df.shift(-1)['STD-YM']
    elif _select == 0:
        # 월초 데이터 조건식
        flag = _df['STD-YM'] != _df.shift(1)['STD-YM']
    else:
        return print('_select의 값은 0 아니면 1 입니다.')
    result = _df.loc[flag]
    
    # 기준이 되는 컬럼의 이름을 변수에 저장
    col = result.columns[0]
    
    # 전월의 기준이 되는 컬럼의 값을 BF1에 대입
    result['BF1'] = result.shift(1)[col]
    # _momentum 값의 과거의 개월 수 데이터  BF2에 대입
    result['BF2'] = result.shift(_momentum)[col]
    try:
        result.index = result.index.dt.tz_localize(None)
    except Exception as e:
        print(e)        
    
    result = result.loc[_start : _end]
    
    
    return result

# %%
# warning 메시지 출력 금지
import warnings
warnings.filterwarnings('ignore')

# %%
df_ym2 = create_month(df_ym,_select = 1, _momentum=6)
# Out:
# 'DatetimeIndex' object has no attribute 'dt'

# %%
df_ym2
# Out:
#               Adj Close   STD-YM          BF1          BF2
# Date
# 2010-01-29   125.410004  2010-01   134.520004    85.760002
# 2010-02-26   118.400002  2010-02   125.410004    81.190002
# 2010-03-31   135.770004  2010-03   118.400002    93.360001
# 2010-04-30   137.100006  2010-04   135.770004   118.809998
# 2010-05-28   125.459999  2010-05   137.100006   135.910004
# ...                 ...      ...          ...          ...
# 2019-02-28  1639.829956  2019-02  1718.729980  2012.709961
# 2019-03-29  1780.750000  2019-03  1639.829956  2003.000000
# 2019-04-30  1926.520020  2019-04  1780.750000  1598.010010
# 2019-05-31  1775.069946  2019-05  1926.520020  1690.170044
# 2019-06-24  1907.953857  2019-06  1775.069946  1501.969971
#
# [114 rows x 4 columns]

# %% [markdown]
# 3. 세번째 함수
# - 매개변수 3개
#     - trade 컬럼이 추가될 데이터 프레임 _df1
#     - 월말/ 월초의 데이터 프레임 _df2 -> create_month함수 결과값
#     - 모멘텀 스코어 설정(_score = 1)
# - _df1의 복사본 생성 (result)
# - result에 trade 컬럼을 생성하고 '' 대입
# - 반복문을 이용하여 구매내역 추가
#     - _df2 데이터프레임 이용하여 momentum_index를 생성
#         - BF1 / BF2 - _score
#         - result에 있는 trade에 buy 대입
# - 구매내역이 추가된 데이터프레임을 되돌려줌

# %%
def create_trade(_df1,
                 _df2, 
                 _score=1):
    result = _df1.copy()
    result['trade'] = ''
    
    try:
        result.index = result.index.tz_localize(None)
    except Exception as e:
        print(e)
        
    # 반복문 생성 -> df2를 기준으로 반복
    for idx in _df2.index:
        signal = ''
        
        momentum_index = _df2.loc[idx, 'BF1'] / _df2.loc[idx, 'BF2'] - _score
        
        flag = momentum_index > 0 and momentum_index != np.inf
        if flag:
            signal = 'buy'
        
        result.loc[idx:, 'trade'] = signal
    
    return result

# %%
df_ym3 = create_trade(df_ym,df_ym2)

# %%
def create_rtn(_df):
    result = _df.copy()
    result['rtn'] = 1

    col = result.columns[0]  # 첫 번째 열을 가격열로 간주
    prev_trade = result['trade'].shift(1)  # 이전 거래 상태 추출

    buy = None  # 매수 가격 저장용

    for idx in result.index:
        if prev_trade.loc[idx] == '' and result.loc[idx, 'trade'] == 'buy':
            buy = result.loc[idx, col]
            print(f'매수일 : {idx}, 매수가 : {buy}')

        elif prev_trade.loc[idx] == 'buy' and result.loc[idx, 'trade'] == '':
            sell = result.loc[idx, col]
            print(f'매도일 : {idx}, 매도가 : {sell}')

            rtn = sell / buy
            result.loc[idx, 'rtn'] = rtn
            print(f'수익률 : {rtn:.4f}')

    result['acc_rtn'] = result['rtn'].cumprod()
    acc_rtn = result['acc_rtn'].iloc[-1]

    return result, acc_rtn

# %%
create_rtn(df_ym3)
# Out:
# 매수일 : 2010-01-29 00:00:00, 매수가 : 125.410004
# 매도일 : 2010-06-30 00:00:00, 매도가 : 109.260002
# 수익률 : 0.8712
# 매수일 : 2010-10-29 00:00:00, 매수가 : 165.229996
# 매도일 : 2011-12-30 00:00:00, 매도가 : 173.100006
# 수익률 : 1.0476
# 매수일 : 2012-05-31 00:00:00, 매수가 : 212.910004
# 매도일 : 2014-04-30 00:00:00, 매도가 : 304.130005
# 수익률 : 1.4284
# 매수일 : 2014-09-30 00:00:00, 매수가 : 322.440002
# 매도일 : 2014-11-28 00:00:00, 매도가 : 338.640015
# 수익률 : 1.0502
# 매수일 : 2014-12-31 00:00:00, 매수가 : 310.350006
# 매도일 : 2015-01-30 00:00:00, 매도가 : 354.529999
# 수익률 : 1.1424
# 매수일 : 2015-02-27 00:00:00, 매수가 : 380.160004
# 매도일 : 2016-04-29 00:00:00, 매도가 : 659.590027
# 수익률 : 1.7350
# 매수일 : 2016-06-30 00:00:00, 매수가 : 715.619995
# 매도일 : 2017-01-31 00:00:00, 매도가 : 823.47998
# 수익률 : 1.1507
# 매수일 : 2017-02-28 00:00:00, 매수가 : 845.039978
# 매도일 : 2018-11-30 00:00:00, 매도가 : 1690.170044
# 수익률 : 2.0001
# 매수일 : 2019-04-30 00:00:00, 매수가 : 1926.52002
# (              Adj Close   STD-YM trade  rtn   acc_rtn
#  Date
#  1997-05-15     1.958333  1997-05        1.0  1.000000
#  1997-05-16     1.729167  1997-05        1.0  1.000000
#  1997-05-19     1.708333  1997-05        1.0  1.000000
#  1997-05-20     1.635417  1997-05        1.0  1.000000
#  1997-05-21     1.427083  1997-05        1.0  1.000000
#  ...                 ...      ...   ...  ...       ...
#  2019-06-18  1901.369995  2019-06   buy  1.0  6.246293
#  2019-06-19  1908.790039  2019-06   buy  1.0  6.246293
#  2019-06-20  1918.189941  2019-06   buy  1.0  6.246293
#  2019-06-21  1911.300049  2019-06   buy  1.0  6.246293
#  2019-06-24  1907.953857  2019-06   buy  1.0  6.246293
#
#  [5563 rows x 5 columns],
#  np.float64(6.2462934745238625))
