# %%
import invest
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import invest
#
# ModuleNotFoundError: No module named 'invest'

# %%
import pandas as pd

# %%
# invest라이브러리
# load_data()
#InvestClass
    # 투자 전략 3개를 사용할 수 있는 클래스
    
df = pd.read_csv('../csv/AAPL.csv')

# %%
df2 = invest.load_data('AAPL')

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close       Volume
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.410525  117258400.0
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.389106   43971200.0
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.360548   26432000.0
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.369472   21610400.0
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.380182   18362400.0

# %%
df2.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-01-04 00:00:00-05:00  6.422878  6.455078  6.391279  6.440332  493729600
# 2010-01-05 00:00:00-05:00  6.458087  6.487879  6.417460  6.451466  601904800
# 2010-01-06 00:00:00-05:00  6.451466  6.477045  6.342226  6.348846  552160000
# 2010-01-07 00:00:00-05:00  6.372319  6.379843  6.291067  6.337110  477131200
# 2010-01-08 00:00:00-05:00  6.328683  6.379842  6.291368  6.379240  447610800
#
#                            Dividends  Stock Splits
# Date
# 2010-01-04 00:00:00-05:00        0.0           0.0
# 2010-01-05 00:00:00-05:00        0.0           0.0
# 2010-01-06 00:00:00-05:00        0.0           0.0
# 2010-01-07 00:00:00-05:00        0.0           0.0
# 2010-01-08 00:00:00-05:00        0.0           0.0

# %%
# Invest Class 생성
class1 = invest.Invest(df)
class2 = invest.Invest(df2, _col = 'Close')

# %%
class1.buyandhold()
# Out:
# 2010-01-01 00:00:00
# 2025-03-26 17:38:05.236845
# Adj Close
# 바이앤홀드 df :  2384
# 2010-01-01부터
#           2025-03-26까지
#           buyandhold의 수익율은 7.436513727083075입니다
# 투자기간 : 2010-01-01 00:00:00 ~ 2025-03-26 17:38:05.236845, 총 수익율 : 7.436513727083075
#              Adj Close  daily_rtn   acc_rtn
# Date
# 2010-01-04   26.782711   1.000000  1.000000
# 2010-01-05   26.829010   1.001729  1.001729
# 2010-01-06   26.402260   0.984094  0.985795
# 2010-01-07   26.353460   0.998152  0.983973
# 2010-01-08   26.528664   1.006648  0.990515
# ...                ...        ...       ...
# 2019-06-18  198.449997   1.023518  7.409631
# 2019-06-19  197.869995   0.997077  7.387975
# 2019-06-20  199.460007   1.008036  7.447342
# 2019-06-21  198.779999   0.996591  7.421952
# 2019-06-24  199.169998   1.001962  7.436514
#
# [2384 rows x 3 columns]

# %%
class1.bollinger()
# Out:
# 매수일 : 2010-01-22 00:00:00, 매수가 : 24.747818
# 매도일 : 2010-03-01 00:00:00, 매도가 : 26.154476
# 수익율 : 1.0568396777445188
# 매수일 : 2010-08-24 00:00:00, 매수가 : 30.026524
# 매도일 : 2010-09-08 00:00:00, 매도가 : 32.90366
# 수익율 : 1.0958198158401553
# 매수일 : 2011-03-16 00:00:00, 매수가 : 41.299767
# 매도일 : 2011-07-01 00:00:00, 매도가 : 42.957966
# 수익율 : 1.040150323366231
# 매수일 : 2011-11-14 00:00:00, 매수가 : 47.463268
# 매도일 : 2011-12-27 00:00:00, 매도가 : 50.876015
# 수익율 : 1.0719029081604747
# c:\Users\Owner\AppData\Local\Programs\Python\Python313\Lib\site-packages\invest\__init__.py:82: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0568396777445188' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   result.loc[idx, 'rtn'] = rtn
# 매수일 : 2012-04-16 00:00:00, 매수가 : 72.601524
# 매도일 : 2012-06-18 00:00:00, 매도가 : 73.308609
# 수익율 : 1.0097392583659814
# 매수일 : 2012-10-08 00:00:00, 매수가 : 80.207954
# ...

# %%
class1.momentum()
# Out:
# c:\Users\Owner\AppData\Local\Programs\Python\Python313\Lib\site-packages\invest\quant\momentum.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['BF1'] = result.shift(1)[col]
# c:\Users\Owner\AppData\Local\Programs\Python\Python313\Lib\site-packages\invest\quant\momentum.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['BF2'] = result.shift(_momentum)[col]
# 날짜 : 2010-01-29 00:00:00, 모멘텀 인덱스 : 1.338067378873177, signal : buy
# ...

# %%
import momentum2 as mmt
import importlib
importlib.reload(mmt)
# Out:
# <module 'momentum2' from 'c:\\Users\\Owner\\Desktop\\ubion_project\\투자전략\\momentum2.py'>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
stock_df,month_last_df = mmt.data_load('./data')

# %%
stock_df.head(3)
# Out:
#             Adj Close   STD-YM  1m_rtn  CODE
# Date
# 2010-01-04  26.782711  2010-01       0  AAPL
# 2010-01-05  26.829010  2010-01       0  AAPL
# 2010-01-06  26.402260  2010-01       0  AAPL

# %%
month_last_df.head(3)
# Out:
#             CODE    1m_rtn
# Date
# 2010-01-29  AAPL  0.897435
# 2010-02-26  AAPL  1.050789
# 2010-03-31  AAPL  1.124456

# %%
sig_dict, stock_code = mmt.create_position(month_last_df,30)

# %%
sig_dict
# Out:
# {Timestamp('2010-01-29 00:00:00'): ['BND', 'GLD'],
#  Timestamp('2010-02-26 00:00:00'): ['AAPL', 'GDX'],
#  Timestamp('2010-03-31 00:00:00'): ['AAPL', 'USM'],
#  Timestamp('2010-04-30 00:00:00'): ['AAPL', 'GDX'],
#  Timestamp('2010-05-28 00:00:00'): ['BND', 'GLD'],
#  Timestamp('2010-06-30 00:00:00'): ['GDX', 'GLD'],
#  Timestamp('2010-07-30 00:00:00'): ['MSFT', 'USM'],
#  Timestamp('2010-08-31 00:00:00'): ['GDX', 'GLD'],
#  Timestamp('2010-09-30 00:00:00'): ['AAPL', 'AMZN'],
#  Timestamp('2010-10-29 00:00:00'): ['MSFT', 'SLV'],
#  Timestamp('2010-11-30 00:00:00'): ['AMZN', 'SLV'],
#  Timestamp('2010-12-31 00:00:00'): ['MSFT', 'SLV'],
#  Timestamp('2011-01-31 00:00:00'): ['AAPL', 'SPY'],
#  Timestamp('2011-02-28 00:00:00'): ['GDX', 'SLV'],
#  Timestamp('2011-03-31 00:00:00'): ['SLV', 'USM'],
#  Timestamp('2011-04-29 00:00:00'): ['GLD', 'SLV'],
#  Timestamp('2011-05-31 00:00:00'): ['BND', 'USM'],
#  Timestamp('2011-06-30 00:00:00'): ['AMZN', 'MSFT'],
# ...

# %%
stock_code
# Out:
# ['AAPL', 'AMZN', 'BND', 'GDX', 'GLD', 'GM', 'MSFT', 'SLV', 'SPY', 'USM']

# %%
book = mmt.create_trade_book(stock_df,stock_code,sig_dict)

# %%
book
# Out:
# CODE              AAPL         AMZN        BND        GDX         GLD  \
# Date
# 2010-01-04   26.782711   133.899994  60.611969  44.908779  109.800003
# 2010-01-05   26.829010   134.690002  60.789135  45.341774  109.699997
# 2010-01-06   26.402260   132.250000  60.766037  46.443077  111.510002
# 2010-01-07   26.353460   130.000000  60.719822  46.217175  110.820000
# 2010-01-08   26.528664   133.520004  60.781410  46.913723  111.370003
# ...                ...          ...        ...        ...         ...
# 2019-06-18  198.449997  1901.369995  82.397118  23.670000  127.120003
# 2019-06-19  197.869995  1908.790039  82.676468  24.000000  127.889999
# 2019-06-20  199.460007  1918.189941  82.806168  25.049999  131.110001
# 2019-06-21  198.779999  1911.300049  82.576698  25.209999  131.979996
# 2019-06-24  199.169998  1907.953857  82.726349  25.703501  133.501907
#
# CODE               GM        MSFT        SLV         SPY        USM  ... p_GM  \
# ...

# %%
trade_book = mmt.create_trading(book, stock_code)

# %%
trade_book['p_AAPL'].value_counts()
# Out:
# p_AAPL
#               1621
# buy_AAPL       727
# ready_AAPL      36
# Name: count, dtype: int64

# %%
trade_rtn = mmt.multi_return(trade_book,stock_code)
# Out:
#  매수일 : 2010-02-01 00:00:00, 매수 가격 : 61.280487, 종목코드 :BND
#  매수일 : 2010-02-01 00:00:00, 매수 가격 : 108.349998, 종목코드 :GLD
#  매수일 : 2010-03-01 00:00:00, 매수 가격 : 26.154476, 종목코드 :AAPL
#  매도일 : 2010-03-01 00:00:00, 매도 가격 : 61.280487, 종목코드 :BND, 수익율 : 1.0049718273289832
#  매수일 : 2010-03-01 00:00:00, 매수 가격 : 42.019035, 종목코드 :GDX
#  매도일 : 2010-03-01 00:00:00, 매도 가격 : 108.349998, 종목코드 :GLD, 수익율 : 1.0099677159200318
#  매도일 : 2010-04-01 00:00:00, 매도 가격 : 42.019035, 종목코드 :GDX, 수익율 : 1.0394266550862008
#  매수일 : 2010-04-01 00:00:00, 매수 가격 : 36.212452, 종목코드 :USM
#  매수일 : 2010-05-03 00:00:00, 매수 가격 : 46.951374, 종목코드 :GDX
#  매도일 : 2010-05-03 00:00:00, 매도 가격 : 36.212452, 종목코드 :USM, 수익율 : 1.0146850039317967
#  매도일 : 2010-06-01 00:00:00, 매도 가격 : 26.154476, 종목코드 :AAPL, 수익율 : 1.248049549912604
#  매수일 : 2010-06-01 00:00:00, 매수 가격 : 62.79007, 종목코드 :BND
#  매도일 : 2010-06-01 00:00:00, 매도 가격 : 46.951374, 종목코드 :GDX, 수익율 : 0.9985966970849457
#  매수일 : 2010-06-01 00:00:00, 매수 가격 : 119.910004, 종목코드 :GLD
# ...

# %%
book, acc_rtn = mmt.multi_acc_return(trade_rtn,stock_code)
# Out:
# 누적 - 매도일 : 2010-03-01 00:00:00, 매도 종목수 : 2, 수익율 : 1.01
# 누적 - 매도일 : 2010-04-01 00:00:00, 매도 종목수 : 1, 수익율 : 1.04
# 누적 - 매도일 : 2010-05-03 00:00:00, 매도 종목수 : 1, 수익율 : 1.01
# 누적 - 매도일 : 2010-06-01 00:00:00, 매도 종목수 : 2, 수익율 : 1.12
# 누적 - 매도일 : 2010-07-01 00:00:00, 매도 종목수 : 1, 수익율 : 1.01
# 누적 - 매도일 : 2010-08-02 00:00:00, 매도 종목수 : 2, 수익율 : 0.97
# 누적 - 매도일 : 2010-09-01 00:00:00, 매도 종목수 : 2, 수익율 : 0.91
# 누적 - 매도일 : 2010-10-01 00:00:00, 매도 종목수 : 2, 수익율 : 1.07
# 누적 - 매도일 : 2010-11-01 00:00:00, 매도 종목수 : 2, 수익율 : 1.07
# 누적 - 매도일 : 2010-12-01 00:00:00, 매도 종목수 : 1, 수익율 : 0.97
# 누적 - 매도일 : 2011-01-03 00:00:00, 매도 종목수 : 1, 수익율 : 1.04
# 누적 - 매도일 : 2011-02-01 00:00:00, 매도 종목수 : 2, 수익율 : 1.08
# 누적 - 매도일 : 2011-03-01 00:00:00, 매도 종목수 : 2, 수익율 : 1.01
# 누적 - 매도일 : 2011-04-01 00:00:00, 매도 종목수 : 1, 수익율 : 0.98
# 누적 - 매도일 : 2011-05-02 00:00:00, 매도 종목수 : 1, 수익율 : 0.94
# 누적 - 매도일 : 2011-06-01 00:00:00, 매도 종목수 : 2, 수익율 : 1.03
# 누적 - 매도일 : 2011-07-01 00:00:00, 매도 종목수 : 2, 수익율 : 1.0
# ...
